# %%
import got
import csv
import pandas as pd
import re

# %%
def makeQuery(term, maxTweets=500, user=''):
    criteria = got.manager.TweetCriteria()
    criteria.setSince("2018-01-01")
    criteria.setUntil("2018-10-28")
    criteria.setQuerySearch(term)
    criteria.setMaxTweets(maxTweets)
    if user!='':
        criteria.setUsername(user)
    t = got.manager.TweetManager.getTweets(criteria)
    return list(filter(lambda x: x.language == 'pt', t))

# %%
bolsonaroQuery = makeQuery("bolsonaro")
bolsonaroList = [tweet.text.encode('utf-8') for tweet in bolsonaroQuery]

#haddadQuery = makeQuery("haddad")
#haddadList = [tweet.text for tweet in haddadQuery]

# %%
with open('tweets.csv','wb') as file:
    for item in bolsonaroList:
        file.write(item + ";")
        file.write("\n")

# %%
# HADDAD
print('\n-----------------------\nHADDAD TWEETS\n')
haddadTweets = makeQuery('haddad')
users = map(lambda x: x.username, haddadTweets)
haddadHistoryTweets = pd.DataFrame(columns=['user','tweet','date','favorites','retweets'])
c = 0
for user in users:
    print('\n---------------------\nuser %i of %i' % (c,len(users)))
    c+=1
    tmp = makeQuery('haddad',maxTweets=200,user=user)
    for i in tmp:
        haddadHistoryTweets = haddadHistoryTweets.append({
            'user': i.username,
            'tweet': i.text,
            'date': i.date,
            'favorites': i.favorites,
            'retweets': i.retweets
        }, ignore_index=True)

display(haddadHistoryTweets.head())
# Out:
# -----------------------
# HADDAD TWEETS
#
#
# ---------------------
# user 0 of 465
#
# ---------------------
# user 1 of 465
#
# ---------------------
# user 2 of 465
#
# ---------------------
# user 3 of 465
#
# ---------------------
# user 4 of 465
#
# ---------------------
# user 5 of 465
#
# ---------------------
# user 6 of 465
#
# ---------------------
# user 7 of 465
#
# ---------------------
# user 8 of 465
#
# ---------------------
# user 9 of 465
#
# ---------------------
# user 10 of 465
#
# ---------------------
# user 11 of 465
#
# ---------------------
# user 12 of 465
#
# ---------------------
# user 13 of 465
#
# ---------------------
# user 14 of 465
#
# ---------------------
# user 15 of 465
#
# ---------------------
# user 16 of 465
#
# ---------------------
# user 17 of 465
#
# ---------------------
# user 18 of 465
#
# ---------------------
# user 19 of 465
#
# ---------------------
# user 20 of 465
#
# ---------------------
# user 21 of 465
#
# ---------------------
# user 22 of 465
#
# ---------------------
# user 23 of 465
#
# ---------------------
# user 24 of 465
#
# ---------------------
# user 25 of 465
#
# ---------------------
# user 26 of 465
#
# ---------------------
# user 27 of 465
#
# ---------------------
# user 28 of 465
#
# ---------------------
# user 29 of 465
#
# ---------------------
# user 30 of 465
#
# ---------------------
# user 31 of 465
#
# ---------------------
# user 32 of 465
#
# ---------------------
# user 33 of 465
#
# ---------------------
# user 34 of 465
#
# ---------------------
# user 35 of 465
#
# ---------------------
# user 36 of 465
#
# ---------------------
# user 37 of 465
#
# ---------------------
# user 38 of 465
#
# ---------------------
# user 39 of 465
#
# ---------------------
# user 40 of 465
#
# ---------------------
# user 41 of 465
#
# ---------------------
# user 42 of 465
#
# ---------------------
# user 43 of 465
#
# ---------------------
# user 44 of 465
#
# ---------------------
# user 45 of 465
#
# ---------------------
# user 46 of 465
#
# ---------------------
# user 47 of 465
#
# ---------------------
# user 48 of 465
#
# ---------------------
# user 49 of 465
#
# ---------------------
# user 50 of 465
#
# ---------------------
# user 51 of 465
#
# ---------------------
# user 52 of 465
#
# ---------------------
# user 53 of 465
#
# ---------------------
# user 54 of 465
#
# ---------------------
# user 55 of 465
#
# ---------------------
# user 56 of 465
#
# ---------------------
# user 57 of 465
#
# ---------------------
# user 58 of 465
#
# ---------------------
# user 59 of 465
#
# ---------------------
# user 60 of 465
#
# ---------------------
# user 61 of 465
#
# ---------------------
# user 62 of 465
#
# ---------------------
# user 63 of 465
#
# ---------------------
# user 64 of 465
#
# ---------------------
# user 65 of 465
#
# ---------------------
# user 66 of 465
#
# ---------------------
# user 67 of 465
#
# ---------------------
# user 68 of 465
#
# ---------------------
# user 69 of 465
#
# ---------------------
# user 70 of 465
#
# ---------------------
# user 71 of 465
#
# ---------------------
# user 72 of 465
#
# ---------------------
# user 73 of 465
#
# ---------------------
# user 74 of 465
#
# ---------------------
# user 75 of 465
#
# ---------------------
# user 76 of 465
#
# ---------------------
# user 77 of 465
#
# ---------------------
# user 78 of 465
#
# ---------------------
# user 79 of 465
#
# ---------------------
# user 80 of 465
#
# ---------------------
# user 81 of 465
#
# ---------------------
# user 82 of 465
#
# ---------------------
# user 83 of 465
#
# ---------------------
# user 84 of 465
#
# ---------------------
# user 85 of 465
#
# ---------------------
# user 86 of 465
#
# ---------------------
# user 87 of 465
#
# ---------------------
# user 88 of 465
#
# ---------------------
# user 89 of 465
#
# ---------------------
# user 90 of 465
#
# ---------------------
# user 91 of 465
#
# ---------------------
# user 92 of 465
#
# ---------------------
# user 93 of 465
#
# ---------------------
# user 94 of 465
#
# ---------------------
# user 95 of 465
#
# ---------------------
# user 96 of 465
#
# ---------------------
# user 97 of 465
#
# ---------------------
# user 98 of 465
#
# ---------------------
# user 99 of 465
#
# ---------------------
# user 100 of 465
#
# ---------------------
# user 101 of 465
#
# ---------------------
# user 102 of 465
#
# ---------------------
# user 103 of 465
#
# ---------------------
# user 104 of 465
#
# ---------------------
# user 105 of 465
#
# ---------------------
# user 106 of 465
#
# ---------------------
# user 107 of 465
#
# ---------------------
# user 108 of 465
#
# ---------------------
# user 109 of 465
#
# ---------------------
# user 110 of 465
#
# ---------------------
# user 111 of 465
#
# ---------------------
# user 112 of 465
#
# ---------------------
# user 113 of 465
#
# ---------------------
# user 114 of 465
#
# ---------------------
# user 115 of 465
#
# ---------------------
# user 116 of 465
#
# ---------------------
# user 117 of 465
#
# ---------------------
# user 118 of 465
#
# ---------------------
# user 119 of 465
#
# ---------------------
# user 120 of 465
#
# ---------------------
# user 121 of 465
#
# ---------------------
# user 122 of 465
#
# ---------------------
# user 123 of 465
#
# ---------------------
# user 124 of 465
#
# ---------------------
# user 125 of 465
#
# ---------------------
# user 126 of 465
#
# ---------------------
# user 127 of 465
#
# ---------------------
# user 128 of 465
#
# ---------------------
# user 129 of 465
#
# ---------------------
# user 130 of 465
#
# ---------------------
# user 131 of 465
#
# ---------------------
# user 132 of 465
#
# ---------------------
# user 133 of 465
#
# ---------------------
# user 134 of 465
#
# ---------------------
# user 135 of 465
#
# ---------------------
# user 136 of 465
#
# ---------------------
# user 137 of 465
#
# ---------------------
# user 138 of 465
#
# ---------------------
# user 139 of 465
#
# ---------------------
# user 140 of 465
#
# ---------------------
# user 141 of 465
#
# ---------------------
# user 142 of 465
#
# ---------------------
# user 143 of 465
#
# ---------------------
# user 144 of 465
#
# ---------------------
# user 145 of 465
#
# ---------------------
# user 146 of 465
#
# ---------------------
# user 147 of 465
#
# ---------------------
# user 148 of 465
#
# ---------------------
# user 149 of 465
#
# ---------------------
# user 150 of 465
#
# ---------------------
# user 151 of 465
#
# ---------------------
# user 152 of 465
#
# ---------------------
# user 153 of 465
#
# ---------------------
# user 154 of 465
#
# ---------------------
# user 155 of 465
#
# ---------------------
# user 156 of 465
#
# ---------------------
# user 157 of 465
#
# ---------------------
# user 158 of 465
#
# ---------------------
# user 159 of 465
#
# ---------------------
# user 160 of 465
#
# ---------------------
# user 161 of 465
#
# ---------------------
# user 162 of 465
#
# ---------------------
# user 163 of 465
#
# ---------------------
# user 164 of 465
#
# ---------------------
# user 165 of 465
#
# ---------------------
# user 166 of 465
#
# ---------------------
# user 167 of 465
#
# ---------------------
# user 168 of 465
#
# ---------------------
# user 169 of 465
#
# ---------------------
# user 170 of 465
#
# ---------------------
# user 171 of 465
#
# ---------------------
# user 172 of 465
#
# ---------------------
# user 173 of 465
#
# ---------------------
# user 174 of 465
#
# ---------------------
# user 175 of 465
#
# ---------------------
# user 176 of 465
#
# ---------------------
# user 177 of 465
#
# ---------------------
# user 178 of 465
#
# ---------------------
# user 179 of 465
#
# ---------------------
# user 180 of 465
#
# ---------------------
# user 181 of 465
#
# ---------------------
# user 182 of 465
#
# ---------------------
# user 183 of 465
#
# ---------------------
# user 184 of 465
#
# ---------------------
# user 185 of 465
#
# ---------------------
# user 186 of 465
#
# ---------------------
# user 187 of 465
#
# ---------------------
# user 188 of 465
#
# ---------------------
# user 189 of 465
#
# ---------------------
# user 190 of 465
#
# ---------------------
# user 191 of 465
#
# ---------------------
# user 192 of 465
#
# ---------------------
# user 193 of 465
#
# ---------------------
# user 194 of 465
#
# ---------------------
# user 195 of 465
#
# ---------------------
# user 196 of 465
#
# ---------------------
# user 197 of 465
#
# ---------------------
# user 198 of 465
#
# ---------------------
# user 199 of 465
#
# ---------------------
# user 200 of 465
#
# ---------------------
# user 201 of 465
#
# ---------------------
# user 202 of 465
#
# ---------------------
# user 203 of 465
#
# ---------------------
# user 204 of 465
#
# ---------------------
# user 205 of 465
#
# ---------------------
# user 206 of 465
#
# ---------------------
# user 207 of 465
#
# ---------------------
# user 208 of 465
#
# ---------------------
# user 209 of 465
#
# ---------------------
# user 210 of 465
#
# ---------------------
# user 211 of 465
# ---------------------
# user 212 of 465
#
# ---------------------
# user 213 of 465
#
# ---------------------
# user 214 of 465
#
# ---------------------
# user 215 of 465
#
# ---------------------
# user 216 of 465
#
# ---------------------
# user 217 of 465
#
# ---------------------
# user 218 of 465
#
# ---------------------
# user 219 of 465
#
# ---------------------
# user 220 of 465
#
# ---------------------
# user 221 of 465
#
# ---------------------
# user 222 of 465
#
# ---------------------
# user 223 of 465
#
# ---------------------
# user 224 of 465
#
# ---------------------
# user 225 of 465
#
# ---------------------
# user 226 of 465
#
# ---------------------
# user 227 of 465
#
# ---------------------
# user 228 of 465
#
# ---------------------
# user 229 of 465
#
# ---------------------
# user 230 of 465
#
# ---------------------
# user 231 of 465
#
# ---------------------
# user 232 of 465
#
# ---------------------
# user 233 of 465
#
# ---------------------
# user 234 of 465
#
# ---------------------
# user 235 of 465
#
# ---------------------
# user 236 of 465
#
# ---------------------
# user 237 of 465
#
# ---------------------
# user 238 of 465
#
# ---------------------
# user 239 of 465
#
# ---------------------
# user 240 of 465
#
# ---------------------
# user 241 of 465
#
# ---------------------
# user 242 of 465
#
# ---------------------
# user 243 of 465
#
# ---------------------
# user 244 of 465
#
# ---------------------
# user 245 of 465
#
# ---------------------
# user 246 of 465
#
# ---------------------
# user 247 of 465
#
# ---------------------
# user 248 of 465
#
# ---------------------
# user 249 of 465
#
# ---------------------
# user 250 of 465
#
# ---------------------
# user 251 of 465
#
# ---------------------
# user 252 of 465
#
# ---------------------
# user 253 of 465
#
# ---------------------
# user 254 of 465
#
# ---------------------
# user 255 of 465
#
# ---------------------
# user 256 of 465
#
# ---------------------
# user 257 of 465
#
# ---------------------
# user 258 of 465
#
# ---------------------
# user 259 of 465
#
# ---------------------
# user 260 of 465
#
# ---------------------
# user 261 of 465
#
# ---------------------
# user 262 of 465
#
# ---------------------
# user 263 of 465
#
# ---------------------
# user 264 of 465
#
# ---------------------
# user 265 of 465
#
# ---------------------
# user 266 of 465
#
# ---------------------
# user 267 of 465
#
# ---------------------
# user 268 of 465
#
# ---------------------
# user 269 of 465
#
# ---------------------
# user 270 of 465
#
# ---------------------
# user 271 of 465
#
# ---------------------
# user 272 of 465
#
# ---------------------
# user 273 of 465
#
# ---------------------
# user 274 of 465
#
# ---------------------
# user 275 of 465
#
# ---------------------
# user 276 of 465
#
# ---------------------
# user 277 of 465
#
# ---------------------
# user 278 of 465
#
# ---------------------
# user 279 of 465
#
# ---------------------
# user 280 of 465
#
# ---------------------
# user 281 of 465
#
# ---------------------
# user 282 of 465
#
# ---------------------
# user 283 of 465
#
# ---------------------
# user 284 of 465
#
# ---------------------
# user 285 of 465
#
# ---------------------
# user 286 of 465
#
# ---------------------
# user 287 of 465
#
# ---------------------
# user 288 of 465
#
# ---------------------
# user 289 of 465
#
# ---------------------
# user 290 of 465
#
# ---------------------
# user 291 of 465
#
# ---------------------
# user 292 of 465
#
# ---------------------
# user 293 of 465
#
# ---------------------
# user 294 of 465
#
# ---------------------
# user 295 of 465
#
# ---------------------
# user 296 of 465
#
# ---------------------
# user 297 of 465
#
# ---------------------
# user 298 of 465
#
# ---------------------
# user 299 of 465
#
# ---------------------
# user 300 of 465
#
# ---------------------
# user 301 of 465
#
# ---------------------
# user 302 of 465
#
# ---------------------
# user 303 of 465
#
# ---------------------
# user 304 of 465
#
# ---------------------
# user 305 of 465
#
# ---------------------
# user 306 of 465
#
# ---------------------
# user 307 of 465
#
# ---------------------
# user 308 of 465
#
# ---------------------
# user 309 of 465
#
# ---------------------
# user 310 of 465
#
# ---------------------
# user 311 of 465
#
# ---------------------
# user 312 of 465
#
# ---------------------
# user 313 of 465
#
# ---------------------
# user 314 of 465
#
# ---------------------
# user 315 of 465
#
# ---------------------
# user 316 of 465
#
# ---------------------
# user 317 of 465
#
# ---------------------
# user 318 of 465
#
# ---------------------
# user 319 of 465
#
# ---------------------
# user 320 of 465
#
# ---------------------
# user 321 of 465
#
# ---------------------
# user 322 of 465
#
# ---------------------
# user 323 of 465
#
# ---------------------
# user 324 of 465
#
# ---------------------
# user 325 of 465
#
# ---------------------
# user 326 of 465
#
# ---------------------
# user 327 of 465
#
# ---------------------
# user 328 of 465
#
# ---------------------
# user 329 of 465
#
# ---------------------
# user 330 of 465
#
# ---------------------
# user 331 of 465
#
# ---------------------
# user 332 of 465
#
# ---------------------
# user 333 of 465
#
# ---------------------
# user 334 of 465
#
# ---------------------
# user 335 of 465
#
# ---------------------
# user 336 of 465
#
# ---------------------
# user 337 of 465
#
# ---------------------
# user 338 of 465
#
# ---------------------
# user 339 of 465
#
# ---------------------
# user 340 of 465
#
# ---------------------
# user 341 of 465
#
# ---------------------
# user 342 of 465
#
# ---------------------
# user 343 of 465
#
# ---------------------
# user 344 of 465
#
# ---------------------
# user 345 of 465
#
# ---------------------
# user 346 of 465
#
# ---------------------
# user 347 of 465
#
# ---------------------
# user 348 of 465
#
# ---------------------
# user 349 of 465
#
# ---------------------
# user 350 of 465
#
# ---------------------
# user 351 of 465
#
# ---------------------
# user 352 of 465
#
# ---------------------
# user 353 of 465
#
# ---------------------
# user 354 of 465
#
# ---------------------
# user 355 of 465
#
# ---------------------
# user 356 of 465
#
# ---------------------
# user 357 of 465
#
# ---------------------
# user 358 of 465
#
# ---------------------
# user 359 of 465
#
# ---------------------
# user 360 of 465
#
# ---------------------
# user 361 of 465
#
# ---------------------
# user 362 of 465
#
# ---------------------
# user 363 of 465
#
# ---------------------
# user 364 of 465
#
# ---------------------
# user 365 of 465
#
# ---------------------
# user 366 of 465
#
# ---------------------
# user 367 of 465
#
# ---------------------
# user 368 of 465
#
# ---------------------
# user 369 of 465
#
# ---------------------
# user 370 of 465
#
# ---------------------
# user 371 of 465
#
# ---------------------
# user 372 of 465
#
# ---------------------
# user 373 of 465
#
# ---------------------
# user 374 of 465
#
# ---------------------
# user 375 of 465
#
# ---------------------
# user 376 of 465
#
# ---------------------
# user 377 of 465
#
# ---------------------
# user 378 of 465
#
# ---------------------
# user 379 of 465
#
# ---------------------
# user 380 of 465
#
# ---------------------
# user 381 of 465
#
# ---------------------
# user 382 of 465
#
# ---------------------
# user 383 of 465
#
# ---------------------
# user 384 of 465
#
# ---------------------
# user 385 of 465
#
# ---------------------
# user 386 of 465
#
# ---------------------
# user 387 of 465
#
# ---------------------
# user 388 of 465
#
# ---------------------
# user 389 of 465
#
# ---------------------
# user 390 of 465
#
# ---------------------
# user 391 of 465
#
# ---------------------
# user 392 of 465
#
# ---------------------
# user 393 of 465
#
# ---------------------
# user 394 of 465
#
# ---------------------
# user 395 of 465
#
# ---------------------
# user 396 of 465
#
# ---------------------
# user 397 of 465
#
# ---------------------
# user 398 of 465
#
# ---------------------
# user 399 of 465
#
# ---------------------
# user 400 of 465
#
# ---------------------
# user 401 of 465
#
# ---------------------
# user 402 of 465
#
# ---------------------
# user 403 of 465
#
# ---------------------
# user 404 of 465
#
# ---------------------
# user 405 of 465
#
# ---------------------
# user 406 of 465
#
# ---------------------
# user 407 of 465
#
# ---------------------
# user 408 of 465
#
# ---------------------
# user 409 of 465
#
# ---------------------
# user 410 of 465
#
# ---------------------
# user 411 of 465
#
# ---------------------
# user 412 of 465
#
# ---------------------
# user 413 of 465
#
# ---------------------
# user 414 of 465
#
# ---------------------
# user 415 of 465
#
# ---------------------
# user 416 of 465
#
# ---------------------
# user 417 of 465
#
# ---------------------
# user 418 of 465
#
# ---------------------
# user 419 of 465
#
# ---------------------
# user 420 of 465
#
# ---------------------
# user 421 of 465
#
# ---------------------
# user 422 of 465
# ---------------------
# user 423 of 465
#
# ---------------------
# user 424 of 465
#
# ---------------------
# user 425 of 465
#
# ---------------------
# user 426 of 465
#
# ---------------------
# user 427 of 465
#
# ---------------------
# user 428 of 465
#
# ---------------------
# user 429 of 465
#
# ---------------------
# user 430 of 465
#
# ---------------------
# user 431 of 465
#
# ---------------------
# user 432 of 465
#
# ---------------------
# user 433 of 465
#
# ---------------------
# user 434 of 465
#
# ---------------------
# user 435 of 465
#
# ---------------------
# user 436 of 465
#
# ---------------------
# user 437 of 465
#
# ---------------------
# user 438 of 465
#
# ---------------------
# user 439 of 465
#
# ---------------------
# user 440 of 465
#
# ---------------------
# user 441 of 465
#
# ---------------------
# user 442 of 465
#
# ---------------------
# user 443 of 465
#
# ---------------------
# user 444 of 465
#
# ---------------------
# user 445 of 465
#
# ---------------------
# user 446 of 465
#
# ---------------------
# user 447 of 465
#
# ---------------------
# user 448 of 465
#
# ---------------------
# user 449 of 465
#
# ---------------------
# user 450 of 465
#
# ---------------------
# user 451 of 465
#
# ---------------------
# user 452 of 465
#
# ---------------------
# user 453 of 465
#
# ---------------------
# user 454 of 465
#
# ---------------------
# user 455 of 465
#
# ---------------------
# user 456 of 465
#
# ---------------------
# user 457 of 465
#
# ---------------------
# user 458 of 465
#
# ---------------------
# user 459 of 465
#
# ---------------------
# user 460 of 465
#
# ---------------------
# user 461 of 465
#
# ---------------------
# user 462 of 465
#
# ---------------------
# user 463 of 465
#
# ---------------------
# user 464 of 465
#           user                                              tweet  \
# 0  LeoAlvvesdf  O @ jornalnacional tá fazendo campanha para o ...
# 1  LeoAlvvesdf  Gostei de um vídeo @ YouTube http://youtu.be/-...
# 2  LeoAlvvesdf  Gostei de um vídeo @ YouTube http://youtu.be/X...
# 3  LeoAlvvesdf  Para que tá feio @ Haddad_Fernando! # MudaBras...
# 4  LeoAlvvesdf  Gostei de um vídeo @ YouTube http://youtu.be/L...
#
#                  date favorites retweets
# 0 2018-10-27 20:59:59         1        0
# 1 2018-10-27 12:23:51         0        0
# 2 2018-10-26 12:32:29         0        0
# 3 2018-10-26 08:18:59         1        0
# 4 2018-10-25 09:30:21         0        0

# %%
# BOZO
print('\n-----------------------\nBOZO TWEETS\n')
bozoTweets = makeQuery('bolsonaro',maxTweets=400)
users = map(lambda x: x.username, bozoTweets)
bozoHistoryTweets = pd.DataFrame(columns=['user','tweet','date','favorites','retweets'])
c = 0
for user in users:
    print('\n---------------------\nuser %i of %i' % (c,len(users)))
    c+=1
    tmp = makeQuery('bolsonaro',maxTweets=200,user=user)
    for i in tmp:
        bozoHistoryTweets = bozoHistoryTweets.append({
            'user': i.username,
            'tweet': i.text,
            'date': i.date,
            'favorites': i.favorites,
            'retweets': i.retweets
        }, ignore_index=True)

display(bozoHistoryTweets.head())
# Out:
# -----------------------
# BOZO TWEETS
#
#
# ---------------------
# user 0 of 352
#
# ---------------------
# user 1 of 352
#
# ---------------------
# user 2 of 352
#
# ---------------------
# user 3 of 352
#
# ---------------------
# user 4 of 352
#
# ---------------------
# user 5 of 352
#
# ---------------------
# user 6 of 352
#
# ---------------------
# user 7 of 352
#
# ---------------------
# user 8 of 352
#
# ---------------------
# user 9 of 352
#
# ---------------------
# user 10 of 352
#
# ---------------------
# user 11 of 352
#
# ---------------------
# user 12 of 352
#
# ---------------------
# user 13 of 352
#
# ---------------------
# user 14 of 352
#
# ---------------------
# user 15 of 352
#
# ---------------------
# user 16 of 352
#
# ---------------------
# user 17 of 352
#
# ---------------------
# user 18 of 352
#
# ---------------------
# user 19 of 352
#
# ---------------------
# user 20 of 352
#
# ---------------------
# user 21 of 352
#
# ---------------------
# user 22 of 352
#
# ---------------------
# user 23 of 352
#
# ---------------------
# user 24 of 352
#
# ---------------------
# user 25 of 352
#
# ---------------------
# user 26 of 352
#
# ---------------------
# user 27 of 352
#
# ---------------------
# user 28 of 352
#
# ---------------------
# user 29 of 352
#
# ---------------------
# user 30 of 352
#
# ---------------------
# user 31 of 352
#
# ---------------------
# user 32 of 352
#
# ---------------------
# user 33 of 352
#
# ---------------------
# user 34 of 352
#
# ---------------------
# user 35 of 352
#
# ---------------------
# user 36 of 352
#
# ---------------------
# user 37 of 352
#
# ---------------------
# user 38 of 352
#
# ---------------------
# user 39 of 352
#
# ---------------------
# user 40 of 352
#
# ---------------------
# user 41 of 352
#
# ---------------------
# user 42 of 352
#
# ---------------------
# user 43 of 352
#
# ---------------------
# user 44 of 352
#
# ---------------------
# user 45 of 352
#
# ---------------------
# user 46 of 352
#
# ---------------------
# user 47 of 352
#
# ---------------------
# user 48 of 352
#
# ---------------------
# user 49 of 352
#
# ---------------------
# user 50 of 352
#
# ---------------------
# user 51 of 352
#
# ---------------------
# user 52 of 352
#
# ---------------------
# user 53 of 352
#
# ---------------------
# user 54 of 352
#
# ---------------------
# user 55 of 352
#
# ---------------------
# user 56 of 352
#
# ---------------------
# user 57 of 352
#
# ---------------------
# user 58 of 352
#
# ---------------------
# user 59 of 352
#
# ---------------------
# user 60 of 352
#
# ---------------------
# user 61 of 352
#
# ---------------------
# user 62 of 352
#
# ---------------------
# user 63 of 352
#
# ---------------------
# user 64 of 352
#
# ---------------------
# user 65 of 352
#
# ---------------------
# user 66 of 352
#
# ---------------------
# user 67 of 352
#
# ---------------------
# user 68 of 352
#
# ---------------------
# user 69 of 352
#
# ---------------------
# user 70 of 352
#
# ---------------------
# user 71 of 352
#
# ---------------------
# user 72 of 352
#
# ---------------------
# user 73 of 352
#
# ---------------------
# user 74 of 352
#
# ---------------------
# user 75 of 352
#
# ---------------------
# user 76 of 352
#
# ---------------------
# user 77 of 352
#
# ---------------------
# user 78 of 352
#
# ---------------------
# user 79 of 352
#
# ---------------------
# user 80 of 352
#
# ---------------------
# user 81 of 352
#
# ---------------------
# user 82 of 352
#
# ---------------------
# user 83 of 352
#
# ---------------------
# user 84 of 352
#
# ---------------------
# user 85 of 352
#
# ---------------------
# user 86 of 352
#
# ---------------------
# user 87 of 352
#
# ---------------------
# user 88 of 352
#
# ---------------------
# user 89 of 352
#
# ---------------------
# user 90 of 352
#
# ---------------------
# user 91 of 352
#
# ---------------------
# user 92 of 352
#
# ---------------------
# user 93 of 352
#
# ---------------------
# user 94 of 352
#
# ---------------------
# user 95 of 352
#
# ---------------------
# user 96 of 352
#
# ---------------------
# user 97 of 352
#
# ---------------------
# user 98 of 352
#
# ---------------------
# user 99 of 352
#
# ---------------------
# user 100 of 352
#
# ---------------------
# user 101 of 352
#
# ---------------------
# user 102 of 352
#
# ---------------------
# user 103 of 352
#
# ---------------------
# user 104 of 352
#
# ---------------------
# user 105 of 352
#
# ---------------------
# user 106 of 352
#
# ---------------------
# user 107 of 352
#
# ---------------------
# user 108 of 352
#
# ---------------------
# user 109 of 352
#
# ---------------------
# user 110 of 352
#
# ---------------------
# user 111 of 352
#
# ---------------------
# user 112 of 352
#
# ---------------------
# user 113 of 352
#
# ---------------------
# user 114 of 352
#
# ---------------------
# user 115 of 352
#
# ---------------------
# user 116 of 352
#
# ---------------------
# user 117 of 352
#
# ---------------------
# user 118 of 352
#
# ---------------------
# user 119 of 352
#
# ---------------------
# user 120 of 352
#
# ---------------------
# user 121 of 352
#
# ---------------------
# user 122 of 352
#
# ---------------------
# user 123 of 352
#
# ---------------------
# user 124 of 352
#
# ---------------------
# user 125 of 352
#
# ---------------------
# user 126 of 352
#
# ---------------------
# user 127 of 352
#
# ---------------------
# user 128 of 352
#
# ---------------------
# user 129 of 352
#
# ---------------------
# user 130 of 352
#
# ---------------------
# user 131 of 352
#
# ---------------------
# user 132 of 352
#
# ---------------------
# user 133 of 352
#
# ---------------------
# user 134 of 352
#
# ---------------------
# user 135 of 352
#
# ---------------------
# user 136 of 352
#
# ---------------------
# user 137 of 352
#
# ---------------------
# user 138 of 352
#
# ---------------------
# user 139 of 352
#
# ---------------------
# user 140 of 352
#
# ---------------------
# user 141 of 352
#
# ---------------------
# user 142 of 352
#
# ---------------------
# user 143 of 352
#
# ---------------------
# user 144 of 352
#
# ---------------------
# user 145 of 352
#
# ---------------------
# user 146 of 352
#
# ---------------------
# user 147 of 352
#
# ---------------------
# user 148 of 352
#
# ---------------------
# user 149 of 352
#
# ---------------------
# user 150 of 352
#
# ---------------------
# user 151 of 352
#
# ---------------------
# user 152 of 352
#
# ---------------------
# user 153 of 352
#
# ---------------------
# user 154 of 352
#
# ---------------------
# user 155 of 352
#
# ---------------------
# user 156 of 352
#
# ---------------------
# user 157 of 352
#
# ---------------------
# user 158 of 352
#
# ---------------------
# user 159 of 352
#
# ---------------------
# user 160 of 352
#
# ---------------------
# user 161 of 352
#
# ---------------------
# user 162 of 352
#
# ---------------------
# user 163 of 352
#
# ---------------------
# user 164 of 352
#
# ---------------------
# user 165 of 352
#
# ---------------------
# user 166 of 352
#
# ---------------------
# user 167 of 352
#
# ---------------------
# user 168 of 352
#
# ---------------------
# user 169 of 352
#
# ---------------------
# user 170 of 352
#
# ---------------------
# user 171 of 352
#
# ---------------------
# user 172 of 352
#
# ---------------------
# user 173 of 352
#
# ---------------------
# user 174 of 352
#
# ---------------------
# user 175 of 352
#
# ---------------------
# user 176 of 352
#
# ---------------------
# user 177 of 352
#
# ---------------------
# user 178 of 352
#
# ---------------------
# user 179 of 352
#
# ---------------------
# user 180 of 352
#
# ---------------------
# user 181 of 352
#
# ---------------------
# user 182 of 352
#
# ---------------------
# user 183 of 352
#
# ---------------------
# user 184 of 352
#
# ---------------------
# user 185 of 352
#
# ---------------------
# user 186 of 352
#
# ---------------------
# user 187 of 352
#
# ---------------------
# user 188 of 352
#
# ---------------------
# user 189 of 352
#
# ---------------------
# user 190 of 352
#
# ---------------------
# user 191 of 352
#
# ---------------------
# user 192 of 352
#
# ---------------------
# user 193 of 352
#
# ---------------------
# user 194 of 352
#
# ---------------------
# user 195 of 352
#
# ---------------------
# user 196 of 352
#
# ---------------------
# user 197 of 352
#
# ---------------------
# user 198 of 352
#
# ---------------------
# user 199 of 352
#
# ---------------------
# user 200 of 352
#
# ---------------------
# user 201 of 352
#
# ---------------------
# user 202 of 352
#
# ---------------------
# user 203 of 352
#
# ---------------------
# user 204 of 352
#
# ---------------------
# user 205 of 352
#
# ---------------------
# user 206 of 352
#
# ---------------------
# user 207 of 352
#
# ---------------------
# user 208 of 352
#
# ---------------------
# user 209 of 352
#
# ---------------------
# user 210 of 352
#
# ---------------------
# user 211 of 352
# ---------------------
# user 212 of 352
#
# ---------------------
# user 213 of 352
#
# ---------------------
# user 214 of 352
#
# ---------------------
# user 215 of 352
#
# ---------------------
# user 216 of 352
#
# ---------------------
# user 217 of 352
#
# ---------------------
# user 218 of 352
#
# ---------------------
# user 219 of 352
#
# ---------------------
# user 220 of 352
#
# ---------------------
# user 221 of 352
#
# ---------------------
# user 222 of 352
#
# ---------------------
# user 223 of 352
#
# ---------------------
# user 224 of 352
#
# ---------------------
# user 225 of 352
#
# ---------------------
# user 226 of 352
#
# ---------------------
# user 227 of 352
#
# ---------------------
# user 228 of 352
#
# ---------------------
# user 229 of 352
#
# ---------------------
# user 230 of 352
#
# ---------------------
# user 231 of 352
#
# ---------------------
# user 232 of 352
#
# ---------------------
# user 233 of 352
#
# ---------------------
# user 234 of 352
#
# ---------------------
# user 235 of 352
#
# ---------------------
# user 236 of 352
#
# ---------------------
# user 237 of 352
#
# ---------------------
# user 238 of 352
#
# ---------------------
# user 239 of 352
#
# ---------------------
# user 240 of 352
#
# ---------------------
# user 241 of 352
#
# ---------------------
# user 242 of 352
#
# ---------------------
# user 243 of 352
#
# ---------------------
# user 244 of 352
#
# ---------------------
# user 245 of 352
#
# ---------------------
# user 246 of 352
#
# ---------------------
# user 247 of 352
#
# ---------------------
# user 248 of 352
#
# ---------------------
# user 249 of 352
#
# ---------------------
# user 250 of 352
#
# ---------------------
# user 251 of 352
#
# ---------------------
# user 252 of 352
#
# ---------------------
# user 253 of 352
#
# ---------------------
# user 254 of 352
#
# ---------------------
# user 255 of 352
#
# ---------------------
# user 256 of 352
#
# ---------------------
# user 257 of 352
#
# ---------------------
# user 258 of 352
#
# ---------------------
# user 259 of 352
#
# ---------------------
# user 260 of 352
#
# ---------------------
# user 261 of 352
#
# ---------------------
# user 262 of 352
#
# ---------------------
# user 263 of 352
#
# ---------------------
# user 264 of 352
#
# ---------------------
# user 265 of 352
#
# ---------------------
# user 266 of 352
#
# ---------------------
# user 267 of 352
#
# ---------------------
# user 268 of 352
#
# ---------------------
# user 269 of 352
#
# ---------------------
# user 270 of 352
#
# ---------------------
# user 271 of 352
#
# ---------------------
# user 272 of 352
#
# ---------------------
# user 273 of 352
#
# ---------------------
# user 274 of 352
#
# ---------------------
# user 275 of 352
#
# ---------------------
# user 276 of 352
#
# ---------------------
# user 277 of 352
#
# ---------------------
# user 278 of 352
#
# ---------------------
# user 279 of 352
#
# ---------------------
# user 280 of 352
#
# ---------------------
# user 281 of 352
#
# ---------------------
# user 282 of 352
#
# ---------------------
# user 283 of 352
#
# ---------------------
# user 284 of 352
#
# ---------------------
# user 285 of 352
#
# ---------------------
# user 286 of 352
#
# ---------------------
# user 287 of 352
#
# ---------------------
# user 288 of 352
#
# ---------------------
# user 289 of 352
#
# ---------------------
# user 290 of 352
#
# ---------------------
# user 291 of 352
#
# ---------------------
# user 292 of 352
#
# ---------------------
# user 293 of 352
#
# ---------------------
# user 294 of 352
#
# ---------------------
# user 295 of 352
#
# ---------------------
# user 296 of 352
#
# ---------------------
# user 297 of 352
#
# ---------------------
# user 298 of 352
#
# ---------------------
# user 299 of 352
#
# ---------------------
# user 300 of 352
#
# ---------------------
# user 301 of 352
#
# ---------------------
# user 302 of 352
#
# ---------------------
# user 303 of 352
#
# ---------------------
# user 304 of 352
#
# ---------------------
# user 305 of 352
#
# ---------------------
# user 306 of 352
#
# ---------------------
# user 307 of 352
#
# ---------------------
# user 308 of 352
#
# ---------------------
# user 309 of 352
#
# ---------------------
# user 310 of 352
#
# ---------------------
# user 311 of 352
#
# ---------------------
# user 312 of 352
#
# ---------------------
# user 313 of 352
#
# ---------------------
# user 314 of 352
#
# ---------------------
# user 315 of 352
#
# ---------------------
# user 316 of 352
#
# ---------------------
# user 317 of 352
#
# ---------------------
# user 318 of 352
#
# ---------------------
# user 319 of 352
#
# ---------------------
# user 320 of 352
#
# ---------------------
# user 321 of 352
#
# ---------------------
# user 322 of 352
#
# ---------------------
# user 323 of 352
#
# ---------------------
# user 324 of 352
#
# ---------------------
# user 325 of 352
#
# ---------------------
# user 326 of 352
#
# ---------------------
# user 327 of 352
#
# ---------------------
# user 328 of 352
#
# ---------------------
# user 329 of 352
#
# ---------------------
# user 330 of 352
#
# ---------------------
# user 331 of 352
#
# ---------------------
# user 332 of 352
#
# ---------------------
# user 333 of 352
#
# ---------------------
# user 334 of 352
#
# ---------------------
# user 335 of 352
#
# ---------------------
# user 336 of 352
#
# ---------------------
# user 337 of 352
#
# ---------------------
# user 338 of 352
#
# ---------------------
# user 339 of 352
#
# ---------------------
# user 340 of 352
#
# ---------------------
# user 341 of 352
#
# ---------------------
# user 342 of 352
#
# ---------------------
# user 343 of 352
#
# ---------------------
# user 344 of 352
#
# ---------------------
# user 345 of 352
#
# ---------------------
# user 346 of 352
#
# ---------------------
# user 347 of 352
#
# ---------------------
# user 348 of 352
#
# ---------------------
# user 349 of 352
#
# ---------------------
# user 350 of 352
#
# ---------------------
# user 351 of 352
#           user                                              tweet  \
# 0  taissarubim  pessoas públicas não devem ter medo de expor s...
# 1  taissarubim  A projeção feita pro ano que vêm com as reform...
# 2  taissarubim  BOLSONARO PRESIDENTE - Como será? https://yout...
# 3  taissarubim  A parada é a seguinte: SE BOLSONARO FOR PRESID...
# 4  taissarubim  As FAKENEWS de Bolsonaro e Haddad / Canal Nost...
#
#                  date favorites retweets
# 0 2018-10-27 20:59:59         1        0
# 1 2018-10-27 20:48:39         0        0
# 2 2018-10-27 20:35:47         0        0
# 3 2018-10-26 17:35:28         6        0
# 4 2018-10-26 17:02:12         1        0

# %%
def altNameQuery(altName):
    print('\n-----------------------\n%s TWEETS\n'%altName)
    bozoAltTweets = makeQuery(altName,maxTweets=34)
    users = map(lambda x: x.username, bozoAltTweets)
    bozoAltHistoryTweets = pd.DataFrame(columns=['user','tweet','date','favorites','retweets'])
    c = 0
    for user in users:
        print('\n---------------------\nuser %i of %i' % (c,len(users)))
        c+=1
        tmp = makeQuery(altName,maxTweets=200,user=user)
        for i in tmp:
            bozoAltHistoryTweets = bozoAltHistoryTweets.append({
                'user': i.username,
                'tweet': i.text,
                'date': i.date,
                'favorites': i.favorites,
                'retweets': i.retweets
            }, ignore_index=True)

    return bozoAltHistoryTweets

# %%
# BOZO ALT NAMES
print('\n-----------------------\nBOZO ALT TWEETS\n')
altNames = ['bozonaro','salnorabo','bonoro']
bozoAltHistoryTweets = pd.DataFrame(columns=['user','tweet','date','favorites','retweets'])
for name in altNames:
    bozoAltHistoryTweets = bozoAltHistoryTweets.append(altNameQuery(name))
    
display(bozoAltHistoryTweets.head())
# Out:
# -----------------------
# BOZO ALT TWEETS
#
#
# -----------------------
# bozonaro TWEETS
#
#
# ---------------------
# user 0 of 32
#
# ---------------------
# user 1 of 32
#
# ---------------------
# user 2 of 32
#
# ---------------------
# user 3 of 32
#
# ---------------------
# user 4 of 32
#
# ---------------------
# user 5 of 32
#
# ---------------------
# user 6 of 32
#
# ---------------------
# user 7 of 32
#
# ---------------------
# user 8 of 32
#
# ---------------------
# user 9 of 32
#
# ---------------------
# user 10 of 32
#
# ---------------------
# user 11 of 32
#
# ---------------------
# user 12 of 32
#
# ---------------------
# user 13 of 32
#
# ---------------------
# user 14 of 32
#
# ---------------------
# user 15 of 32
#
# ---------------------
# user 16 of 32
#
# ---------------------
# user 17 of 32
#
# ---------------------
# user 18 of 32
#
# ---------------------
# user 19 of 32
#
# ---------------------
# user 20 of 32
#
# ---------------------
# user 21 of 32
#
# ---------------------
# user 22 of 32
#
# ---------------------
# user 23 of 32
#
# ---------------------
# user 24 of 32
#
# ---------------------
# user 25 of 32
#
# ---------------------
# user 26 of 32
#
# ---------------------
# user 27 of 32
#
# ---------------------
# user 28 of 32
#
# ---------------------
# user 29 of 32
#
# ---------------------
# user 30 of 32
#
# ---------------------
# user 31 of 32
#
# -----------------------
# salnorabo TWEETS
#
#
# ---------------------
# user 0 of 33
#
# ---------------------
# user 1 of 33
#
# ---------------------
# user 2 of 33
#
# ---------------------
# user 3 of 33
#
# ---------------------
# user 4 of 33
#
# ---------------------
# user 5 of 33
#
# ---------------------
# user 6 of 33
#
# ---------------------
# user 7 of 33
#
# ---------------------
# user 8 of 33
#
# ---------------------
# user 9 of 33
#
# ---------------------
# user 10 of 33
#
# ---------------------
# user 11 of 33
#
# ---------------------
# user 12 of 33
#
# ---------------------
# user 13 of 33
#
# ---------------------
# user 14 of 33
#
# ---------------------
# user 15 of 33
#
# ---------------------
# user 16 of 33
#
# ---------------------
# user 17 of 33
#
# ---------------------
# user 18 of 33
#
# ---------------------
# user 19 of 33
#
# ---------------------
# user 20 of 33
#
# ---------------------
# user 21 of 33
#
# ---------------------
# user 22 of 33
#
# ---------------------
# user 23 of 33
#
# ---------------------
# user 24 of 33
#
# ---------------------
# user 25 of 33
#
# ---------------------
# user 26 of 33
#
# ---------------------
# user 27 of 33
#
# ---------------------
# user 28 of 33
#
# ---------------------
# user 29 of 33
#
# ---------------------
# user 30 of 33
#
# ---------------------
# user 31 of 33
#
# ---------------------
# user 32 of 33
#
# -----------------------
# bonoro TWEETS
#
#
# ---------------------
# user 0 of 34
#
# ---------------------
# user 1 of 34
#
# ---------------------
# user 2 of 34
#
# ---------------------
# user 3 of 34
#
# ---------------------
# user 4 of 34
#
# ---------------------
# user 5 of 34
#
# ---------------------
# user 6 of 34
#
# ---------------------
# user 7 of 34
#
# ---------------------
# user 8 of 34
#
# ---------------------
# user 9 of 34
#
# ---------------------
# user 10 of 34
#
# ---------------------
# user 11 of 34
#
# ---------------------
# user 12 of 34
#
# ---------------------
# user 13 of 34
#
# ---------------------
# user 14 of 34
#
# ---------------------
# user 15 of 34
#
# ---------------------
# user 16 of 34
#
# ---------------------
# user 17 of 34
#
# ---------------------
# user 18 of 34
#
# ---------------------
# user 19 of 34
#
# ---------------------
# user 20 of 34
#
# ---------------------
# user 21 of 34
#
# ---------------------
# user 22 of 34
#
# ---------------------
# user 23 of 34
#
# ---------------------
# user 24 of 34
#
# ---------------------
# user 25 of 34
#
# ---------------------
# user 26 of 34
#
# ---------------------
# user 27 of 34
#
# ---------------------
# user 28 of 34
#
# ---------------------
# user 29 of 34
#
# ---------------------
# user 30 of 34
#
# ---------------------
# user 31 of 34
#
# ---------------------
# user 32 of 34
#
# ---------------------
# user 33 of 34
#            user                                              tweet  \
# 0  ambitchiious  você usa droga, ama um baile de favela, aborto...
# 1  ambitchiious  o bozonaro foi ferido com uma arma branca, ima...
# 2       kevysu1                  fala cotista que apoia o bozonaro
# 3       kevysu1                          Aqui é bozonaro 2018 Flws
# 4       kevysu1  se algum eleitor do bozonaro me segue pfvr faç...
#
#                  date favorites retweets
# 0 2018-10-27 20:59:33         1        0
# 1 2018-09-06 16:37:13         0        0
# 2 2018-10-27 20:59:16         0        0
# 3 2018-08-20 19:25:23         0        0
# 4 2018-07-20 10:09:29         4        1

# %%
#remove tweets that contains bolsonaro and haddad comments together
cleanBozoTweets = bozoHistoryTweets[bozoHistoryTweets.tweet.str.contains('lula|haddad|pt')]
cleanHaddadTweets = haddadHistoryTweets[haddadHistoryTweets.tweet.str.contains('bolsonaro')]

def linkRemover(string):
    return re.sub(r'http\S+', '', string)

cleanBozoTweets['tweet'].apply(lambda s: linkRemover(s))
print(cleanBozoTweets.iloc[0].tweet)

cleanHaddadTweets.to_csv('haddad.csv',sep=',',encoding='utf-8')
cleanBozoTweets.to_csv('bozo.csv',sep=',',encoding='utf-8')
bozoAltHistoryTweets.to_csv('bozoAlt.csv',sep=',',encoding='utf-8')
# Out:
# Janaína afirma “Votar em Bolsonaro virou ato de resistência aos corruptos” https://republicadecuritiba.net/2018/10/03/janaina-afirma-votar-em-bolsonaro-virou-ato-de-resistencia-aos-corruptos/ …

# %%
#analise de sentimentos
from textblob import TextBlob
import re
def clean_text(txt):
    txt = re.sub(r'http\S+', '', txt)
    return txt
i = 0
for t in bolsonaroList:
    print(clean_text(t))
    frase = TextBlob(clean_text(t).decode('utf-8'))
    if frase.detect_language() != 'en':
        traducao = TextBlob(str(frase.translate(to='en')))
        print('Tweet: {0} - Sentimento: {1}'.format(t, traducao.sentiment))
    else:
        print('Tweet: {0} - Sentimento: {1}'.format(t, frase.sentiment))
    i = i+1
    if i == 10:
        break

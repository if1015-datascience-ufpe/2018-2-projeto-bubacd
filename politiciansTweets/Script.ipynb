# %%
import got
import csv
import pandas as pd
import re

# %%
def makeQuery(term, maxTweets=500, user=''):
    criteria = got.manager.TweetCriteria()
    criteria.setSince("2018-01-01")
    criteria.setUntil("2018-10-28")
    criteria.setQuerySearch(term)
    criteria.setMaxTweets(maxTweets)
    if user!='':
        criteria.setUsername(user)
    t = got.manager.TweetManager.getTweets(criteria)
    return list(filter(lambda x: x.language == 'pt', t))

# %%
bolsonaroQuery = makeQuery("bolsonaro")
bolsonaroList = [tweet.text.encode('utf-8') for tweet in bolsonaroQuery]

#haddadQuery = makeQuery("haddad")
#haddadList = [tweet.text for tweet in haddadQuery]

# %%
with open('tweets.csv','wb') as file:
    for item in bolsonaroList:
        file.write(item + ";")
        file.write("\n")

# %%
# HADDAD
print('\n-----------------------\nHADDAD TWEETS\n')
haddadTweets = makeQuery('haddad')
users = map(lambda x: x.username, haddadTweets)
haddadHistoryTweets = pd.DataFrame(columns=['user','tweet','date','favorites','retweets'])
print(haddadTweets)
c = 0
for user in users:
    print('\n---------------------\nuser %i of %i' % (c,len(users)))
    c+=1
    tmp = makeQuery('haddad',maxTweets=200,user=user)
    for i in tmp:
        haddadHistoryTweets = haddadHistoryTweets.append({
            'user': i.username,
            'tweet': i.text,
            'date': i.date,
            'favorites': i.favorites,
            'retweets': i.retweets
        }, ignore_index=True)

display(haddadHistoryTweets.head())
# Out:
# -----------------------
# HADDAD TWEETS
#
# [<got.models.Tweet.Tweet instance at 0x00000000184D1588>, <got.models.Tweet.Tweet instance at 0x00000000182A2E48>, <got.models.Tweet.Tweet instance at 0x00000000184E9588>, <got.models.Tweet.Tweet instance at 0x00000000187AFF48>, <got.models.Tweet.Tweet instance at 0x000000001828AB08>, <got.models.Tweet.Tweet instance at 0x00000000184CEAC8>, <got.models.Tweet.Tweet instance at 0x00000000187AF508>, <got.models.Tweet.Tweet instance at 0x00000000184E9E08>, <got.models.Tweet.Tweet instance at 0x0000000018591788>, <got.models.Tweet.Tweet instance at 0x00000000185916C8>, <got.models.Tweet.Tweet instance at 0x00000000184D1088>, <got.models.Tweet.Tweet instance at 0x00000000186FFAC8>, <got.models.Tweet.Tweet instance at 0x000000001859C808>, <got.models.Tweet.Tweet instance at 0x00000000184CE9C8>, <got.models.Tweet.Tweet instance at 0x00000000184DD588>, <got.models.Tweet.Tweet instance at 0x00000000184DD448>, <got.models.Tweet.Tweet instance at 0x00000000184CE5C8>, <got.models.Tweet.Tweet instance at 0x000000001859CD88>, <got.models.Tweet.Tweet instance at 0x00000000184D19C8>, <got.models.Tweet.Tweet instance at 0x00000000184D1F88>, <got.models.Tweet.Tweet instance at 0x00000000184E9DC8>, <got.models.Tweet.Tweet instance at 0x00000000182D7B88>, <got.models.Tweet.Tweet instance at 0x00000000184DD508>, <got.models.Tweet.Tweet instance at 0x00000000184DD908>, <got.models.Tweet.Tweet instance at 0x00000000184DDD48>, <got.models.Tweet.Tweet instance at 0x00000000184DDD88>, <got.models.Tweet.Tweet instance at 0x00000000184DDBC8>, <got.models.Tweet.Tweet instance at 0x00000000184DD0C8>, <got.models.Tweet.Tweet instance at 0x00000000184DD288>, <got.models.Tweet.Tweet instance at 0x00000000182D7688>, <got.models.Tweet.Tweet instance at 0x00000000182AD088>, <got.models.Tweet.Tweet instance at 0x00000000184D1988>, <got.models.Tweet.Tweet instance at 0x00000000184D1BC8>, <got.models.Tweet.Tweet instance at 0x000000001859C748>, <got.models.Tweet.Tweet instance at 0x00000000184CED88>, <got.models.Tweet.Tweet instance at 0x00000000184D17C8>, <got.models.Tweet.Tweet instance at 0x00000000184D1A08>, <got.models.Tweet.Tweet instance at 0x00000000184E93C8>, <got.models.Tweet.Tweet instance at 0x00000000184CE948>, <got.models.Tweet.Tweet instance at 0x00000000182DA388>, <got.models.Tweet.Tweet instance at 0x0000000018591608>, <got.models.Tweet.Tweet instance at 0x00000000184DDF08>, <got.models.Tweet.Tweet instance at 0x00000000184DDC88>, <got.models.Tweet.Tweet instance at 0x0000000018782EC8>, <got.models.Tweet.Tweet instance at 0x00000000184DD2C8>, <got.models.Tweet.Tweet instance at 0x00000000184DDB88>, <got.models.Tweet.Tweet instance at 0x00000000184DD5C8>, <got.models.Tweet.Tweet instance at 0x00000000184DD3C8>, <got.models.Tweet.Tweet instance at 0x000000000556CE88>, <got.models.Tweet.Tweet instance at 0x00000000184D10C8>, <got.models.Tweet.Tweet instance at 0x00000000184D1108>, <got.models.Tweet.Tweet instance at 0x00000000184D14C8>, <got.models.Tweet.Tweet instance at 0x00000000182B6788>, <got.models.Tweet.Tweet instance at 0x00000000184DDA88>, <got.models.Tweet.Tweet instance at 0x00000000187AFFC8>, <got.models.Tweet.Tweet instance at 0x00000000182DA2C8>, <got.models.Tweet.Tweet instance at 0x00000000185910C8>, <got.models.Tweet.Tweet instance at 0x00000000183EF188>, <got.models.Tweet.Tweet instance at 0x00000000183EF4C8>, <got.models.Tweet.Tweet instance at 0x00000000183EF8C8>, <got.models.Tweet.Tweet instance at 0x00000000182D1A88>, <got.models.Tweet.Tweet instance at 0x0000000018591F08>, <got.models.Tweet.Tweet instance at 0x0000000018782148>, <got.models.Tweet.Tweet instance at 0x00000000184E9EC8>, <got.models.Tweet.Tweet instance at 0x00000000184E9948>, <got.models.Tweet.Tweet instance at 0x00000000184D1348>, <got.models.Tweet.Tweet instance at 0x00000000184D1C48>, <got.models.Tweet.Tweet instance at 0x00000000183EF648>, <got.models.Tweet.Tweet instance at 0x00000000183EF248>, <got.models.Tweet.Tweet instance at 0x00000000183EFB48>, <got.mode ...
#
# ---------------------
# user 0 of 466
# ---------------------
# user 1 of 466
#
# ---------------------
# user 2 of 466
#
# ---------------------
# user 3 of 466
#
# ---------------------
# user 4 of 466
#
# ---------------------
# user 5 of 466
#
# ---------------------
# user 6 of 466
#
# ---------------------
# user 7 of 466
#
# ---------------------
# user 8 of 466
#
# ---------------------
# user 9 of 466
#
# ---------------------
# user 10 of 466
#
# ---------------------
# user 11 of 466
#
# ---------------------
# user 12 of 466
#
# ---------------------
# user 13 of 466
#
# ---------------------
# user 14 of 466
#
# ---------------------
# user 15 of 466
#
# ---------------------
# user 16 of 466
#
# ---------------------
# user 17 of 466
#
# ---------------------
# user 18 of 466
#
# ---------------------
# user 19 of 466
#
# ---------------------
# user 20 of 466
#
# ---------------------
# user 21 of 466
#
# ---------------------
# user 22 of 466
#
# ---------------------
# user 23 of 466
#
# ---------------------
# user 24 of 466
#
# ---------------------
# user 25 of 466
#
# ---------------------
# user 26 of 466
#
# ---------------------
# user 27 of 466
#
# ---------------------
# user 28 of 466
#
# ---------------------
# user 29 of 466
#
# ---------------------
# user 30 of 466
#
# ---------------------
# user 31 of 466
#
# ---------------------
# user 32 of 466
#
# ---------------------
# user 33 of 466
#
# ---------------------
# user 34 of 466
#
# ---------------------
# user 35 of 466
#
# ---------------------
# user 36 of 466
#
# ---------------------
# user 37 of 466
#
# ---------------------
# user 38 of 466
#
# ---------------------
# user 39 of 466
#
# ---------------------
# user 40 of 466
#
# ---------------------
# user 41 of 466
#
# ---------------------
# user 42 of 466
#
# ---------------------
# user 43 of 466
#
# ---------------------
# user 44 of 466
#
# ---------------------
# user 45 of 466
#
# ---------------------
# user 46 of 466
#
# ---------------------
# user 47 of 466
#
# ---------------------
# user 48 of 466
#
# ---------------------
# user 49 of 466
#
# ---------------------
# user 50 of 466
#
# ---------------------
# user 51 of 466
#
# ---------------------
# user 52 of 466
#
# ---------------------
# user 53 of 466
#
# ---------------------
# user 54 of 466
#
# ---------------------
# user 55 of 466
#
# ---------------------
# user 56 of 466
#
# ---------------------
# user 57 of 466
#
# ---------------------
# user 58 of 466
#
# ---------------------
# user 59 of 466
#
# ---------------------
# user 60 of 466
#
# ---------------------
# user 61 of 466
#
# ---------------------
# user 62 of 466
#
# ---------------------
# user 63 of 466
#
# ---------------------
# user 64 of 466
#
# ---------------------
# user 65 of 466
#
# ---------------------
# user 66 of 466
#
# ---------------------
# user 67 of 466
#
# ---------------------
# user 68 of 466
#
# ---------------------
# user 69 of 466
#
# ---------------------
# user 70 of 466
#
# ---------------------
# user 71 of 466
#
# ---------------------
# user 72 of 466
#
# ---------------------
# user 73 of 466
#
# ---------------------
# user 74 of 466
#
# ---------------------
# user 75 of 466
#
# ---------------------
# user 76 of 466
#
# ---------------------
# user 77 of 466
#
# ---------------------
# user 78 of 466
#
# ---------------------
# user 79 of 466
#
# ---------------------
# user 80 of 466
#
# ---------------------
# user 81 of 466
#
# ---------------------
# user 82 of 466
#
# ---------------------
# user 83 of 466
#
# ---------------------
# user 84 of 466
#
# ---------------------
# user 85 of 466
#
# ---------------------
# user 86 of 466
#
# ---------------------
# user 87 of 466
#
# ---------------------
# user 88 of 466
#
# ---------------------
# user 89 of 466
#
# ---------------------
# user 90 of 466
#
# ---------------------
# user 91 of 466
#
# ---------------------
# user 92 of 466
#
# ---------------------
# user 93 of 466
#
# ---------------------
# user 94 of 466
#
# ---------------------
# user 95 of 466
#
# ---------------------
# user 96 of 466
#
# ---------------------
# user 97 of 466
#
# ---------------------
# user 98 of 466
#
# ---------------------
# user 99 of 466
#
# ---------------------
# user 100 of 466
#
# ---------------------
# user 101 of 466
#
# ---------------------
# user 102 of 466
#
# ---------------------
# user 103 of 466
#
# ---------------------
# user 104 of 466
#
# ---------------------
# user 105 of 466
#
# ---------------------
# user 106 of 466
#
# ---------------------
# user 107 of 466
#
# ---------------------
# user 108 of 466
#
# ---------------------
# user 109 of 466
#
# ---------------------
# user 110 of 466
#
# ---------------------
# user 111 of 466
#
# ---------------------
# user 112 of 466
#
# ---------------------
# user 113 of 466
#
# ---------------------
# user 114 of 466
#
# ---------------------
# user 115 of 466
#
# ---------------------
# user 116 of 466
#
# ---------------------
# user 117 of 466
#
# ---------------------
# user 118 of 466
#
# ---------------------
# user 119 of 466
#
# ---------------------
# user 120 of 466
#
# ---------------------
# user 121 of 466
#
# ---------------------
# user 122 of 466
#
# ---------------------
# user 123 of 466
#
# ---------------------
# user 124 of 466
#
# ---------------------
# user 125 of 466
#
# ---------------------
# user 126 of 466
#
# ---------------------
# user 127 of 466
#
# ---------------------
# user 128 of 466
#
# ---------------------
# user 129 of 466
#
# ---------------------
# user 130 of 466
#
# ---------------------
# user 131 of 466
#
# ---------------------
# user 132 of 466
#
# ---------------------
# user 133 of 466
#
# ---------------------
# user 134 of 466
#
# ---------------------
# user 135 of 466
#
# ---------------------
# user 136 of 466
#
# ---------------------
# user 137 of 466
#
# ---------------------
# user 138 of 466
#
# ---------------------
# user 139 of 466
#
# ---------------------
# user 140 of 466
#
# ---------------------
# user 141 of 466
#
# ---------------------
# user 142 of 466
#
# ---------------------
# user 143 of 466
#
# ---------------------
# user 144 of 466
#
# ---------------------
# user 145 of 466
#
# ---------------------
# user 146 of 466
#
# ---------------------
# user 147 of 466
#
# ---------------------
# user 148 of 466
#
# ---------------------
# user 149 of 466
#
# ---------------------
# user 150 of 466
#
# ---------------------
# user 151 of 466
#
# ---------------------
# user 152 of 466
#
# ---------------------
# user 153 of 466
#
# ---------------------
# user 154 of 466
#
# ---------------------
# user 155 of 466
#
# ---------------------
# user 156 of 466
#
# ---------------------
# user 157 of 466
#
# ---------------------
# user 158 of 466
#
# ---------------------
# user 159 of 466
#
# ---------------------
# user 160 of 466
#
# ---------------------
# user 161 of 466
#
# ---------------------
# user 162 of 466
#
# ---------------------
# user 163 of 466
#
# ---------------------
# user 164 of 466
#
# ---------------------
# user 165 of 466
#
# ---------------------
# user 166 of 466
#
# ---------------------
# user 167 of 466
#
# ---------------------
# user 168 of 466
#
# ---------------------
# user 169 of 466
#
# ---------------------
# user 170 of 466
#
# ---------------------
# user 171 of 466
#
# ---------------------
# user 172 of 466
#
# ---------------------
# user 173 of 466
#
# ---------------------
# user 174 of 466
#
# ---------------------
# user 175 of 466
#
# ---------------------
# user 176 of 466
#
# ---------------------
# user 177 of 466
#
# ---------------------
# user 178 of 466
#
# ---------------------
# user 179 of 466
#
# ---------------------
# user 180 of 466
#
# ---------------------
# user 181 of 466
#
# ---------------------
# user 182 of 466
#
# ---------------------
# user 183 of 466
#
# ---------------------
# user 184 of 466
#
# ---------------------
# user 185 of 466
#
# ---------------------
# user 186 of 466
#
# ---------------------
# user 187 of 466
#
# ---------------------
# user 188 of 466
#
# ---------------------
# user 189 of 466
#
# ---------------------
# user 190 of 466
#
# ---------------------
# user 191 of 466
#
# ---------------------
# user 192 of 466
#
# ---------------------
# user 193 of 466
#
# ---------------------
# user 194 of 466
#
# ---------------------
# user 195 of 466
#
# ---------------------
# user 196 of 466
#
# ---------------------
# user 197 of 466
#
# ---------------------
# user 198 of 466
#
# ---------------------
# user 199 of 466
#
# ---------------------
# user 200 of 466
#
# ---------------------
# user 201 of 466
#
# ---------------------
# user 202 of 466
#
# ---------------------
# user 203 of 466
#
# ---------------------
# user 204 of 466
#
# ---------------------
# user 205 of 466
#
# ---------------------
# user 206 of 466
#
# ---------------------
# user 207 of 466
#
# ---------------------
# user 208 of 466
#
# ---------------------
# user 209 of 466
#
# ---------------------
# user 210 of 466
#
# ---------------------
# user 211 of 466
#
# ---------------------
# user 212 of 466
#
# ---------------------
# user 213 of 466
# ---------------------
# user 214 of 466
#
# ---------------------
# user 215 of 466
#
# ---------------------
# user 216 of 466
#
# ---------------------
# user 217 of 466
#
# ---------------------
# user 218 of 466
#
# ---------------------
# user 219 of 466
#
# ---------------------
# user 220 of 466
#
# ---------------------
# user 221 of 466
#
# ---------------------
# user 222 of 466
#
# ---------------------
# user 223 of 466
#
# ---------------------
# user 224 of 466
#
# ---------------------
# user 225 of 466
#
# ---------------------
# user 226 of 466
#
# ---------------------
# user 227 of 466
#
# ---------------------
# user 228 of 466
#
# ---------------------
# user 229 of 466
#
# ---------------------
# user 230 of 466
#
# ---------------------
# user 231 of 466
#
# ---------------------
# user 232 of 466
#
# ---------------------
# user 233 of 466
#
# ---------------------
# user 234 of 466
#
# ---------------------
# user 235 of 466
#
# ---------------------
# user 236 of 466
#
# ---------------------
# user 237 of 466
#
# ---------------------
# user 238 of 466
#
# ---------------------
# user 239 of 466
#
# ---------------------
# user 240 of 466
#
# ---------------------
# user 241 of 466
#
# ---------------------
# user 242 of 466
#
# ---------------------
# user 243 of 466
#
# ---------------------
# user 244 of 466
#
# ---------------------
# user 245 of 466
#
# ---------------------
# user 246 of 466
#
# ---------------------
# user 247 of 466
#
# ---------------------
# user 248 of 466
#
# ---------------------
# user 249 of 466
#
# ---------------------
# user 250 of 466
#
# ---------------------
# user 251 of 466
#
# ---------------------
# user 252 of 466
#
# ---------------------
# user 253 of 466
#
# ---------------------
# user 254 of 466
#
# ---------------------
# user 255 of 466
#
# ---------------------
# user 256 of 466
#
# ---------------------
# user 257 of 466
#
# ---------------------
# user 258 of 466
#
# ---------------------
# user 259 of 466
#
# ---------------------
# user 260 of 466
#
# ---------------------
# user 261 of 466
#
# ---------------------
# user 262 of 466
#
# ---------------------
# user 263 of 466
#
# ---------------------
# user 264 of 466
#
# ---------------------
# user 265 of 466
#
# ---------------------
# user 266 of 466
#
# ---------------------
# user 267 of 466
#
# ---------------------
# user 268 of 466
#
# ---------------------
# user 269 of 466
#
# ---------------------
# user 270 of 466
#
# ---------------------
# user 271 of 466
#
# ---------------------
# user 272 of 466
#
# ---------------------
# user 273 of 466
#
# ---------------------
# user 274 of 466
#
# ---------------------
# user 275 of 466
#
# ---------------------
# user 276 of 466
#
# ---------------------
# user 277 of 466
#
# ---------------------
# user 278 of 466
#
# ---------------------
# user 279 of 466
#
# ---------------------
# user 280 of 466
#
# ---------------------
# user 281 of 466
#
# ---------------------
# user 282 of 466
#
# ---------------------
# user 283 of 466
#
# ---------------------
# user 284 of 466
#
# ---------------------
# user 285 of 466
#
# ---------------------
# user 286 of 466
#
# ---------------------
# user 287 of 466
#
# ---------------------
# user 288 of 466
#
# ---------------------
# user 289 of 466
#
# ---------------------
# user 290 of 466
#
# ---------------------
# user 291 of 466
#
# ---------------------
# user 292 of 466
#
# ---------------------
# user 293 of 466
#
# ---------------------
# user 294 of 466
#
# ---------------------
# user 295 of 466
#
# ---------------------
# user 296 of 466
#
# ---------------------
# user 297 of 466
#
# ---------------------
# user 298 of 466
#
# ---------------------
# user 299 of 466
#
# ---------------------
# user 300 of 466
#
# ---------------------
# user 301 of 466
#
# ---------------------
# user 302 of 466
#
# ---------------------
# user 303 of 466
#
# ---------------------
# user 304 of 466
#
# ---------------------
# user 305 of 466
#
# ---------------------
# user 306 of 466
#
# ---------------------
# user 307 of 466
#
# ---------------------
# user 308 of 466
#
# ---------------------
# user 309 of 466
#
# ---------------------
# user 310 of 466
#
# ---------------------
# user 311 of 466
#
# ---------------------
# user 312 of 466
#
# ---------------------
# user 313 of 466
#
# ---------------------
# user 314 of 466
#
# ---------------------
# user 315 of 466
#
# ---------------------
# user 316 of 466
#
# ---------------------
# user 317 of 466
#
# ---------------------
# user 318 of 466
#
# ---------------------
# user 319 of 466
#
# ---------------------
# user 320 of 466
#
# ---------------------
# user 321 of 466
#
# ---------------------
# user 322 of 466
#
# ---------------------
# user 323 of 466
#
# ---------------------
# user 324 of 466
#
# ---------------------
# user 325 of 466
#
# ---------------------
# user 326 of 466
#
# ---------------------
# user 327 of 466
#
# ---------------------
# user 328 of 466
#
# ---------------------
# user 329 of 466
#
# ---------------------
# user 330 of 466
#
# ---------------------
# user 331 of 466
#
# ---------------------
# user 332 of 466
#
# ---------------------
# user 333 of 466
#
# ---------------------
# user 334 of 466
#
# ---------------------
# user 335 of 466
#
# ---------------------
# user 336 of 466
#
# ---------------------
# user 337 of 466
#
# ---------------------
# user 338 of 466
#
# ---------------------
# user 339 of 466
#
# ---------------------
# user 340 of 466
#
# ---------------------
# user 341 of 466
#
# ---------------------
# user 342 of 466
#
# ---------------------
# user 343 of 466
#
# ---------------------
# user 344 of 466
#
# ---------------------
# user 345 of 466
#
# ---------------------
# user 346 of 466
#
# ---------------------
# user 347 of 466
#
# ---------------------
# user 348 of 466
#
# ---------------------
# user 349 of 466
#
# ---------------------
# user 350 of 466
#
# ---------------------
# user 351 of 466
#
# ---------------------
# user 352 of 466
#
# ---------------------
# user 353 of 466
#
# ---------------------
# user 354 of 466
#
# ---------------------
# user 355 of 466
#
# ---------------------
# user 356 of 466
#
# ---------------------
# user 357 of 466
#
# ---------------------
# user 358 of 466
#
# ---------------------
# user 359 of 466
#
# ---------------------
# user 360 of 466
#
# ---------------------
# user 361 of 466
#
# ---------------------
# user 362 of 466
#
# ---------------------
# user 363 of 466
#
# ---------------------
# user 364 of 466
#
# ---------------------
# user 365 of 466
#
# ---------------------
# user 366 of 466
#
# ---------------------
# user 367 of 466
#
# ---------------------
# user 368 of 466
#
# ---------------------
# user 369 of 466
#
# ---------------------
# user 370 of 466
#
# ---------------------
# user 371 of 466
#
# ---------------------
# user 372 of 466
#
# ---------------------
# user 373 of 466
#
# ---------------------
# user 374 of 466
#
# ---------------------
# user 375 of 466
#
# ---------------------
# user 376 of 466
#
# ---------------------
# user 377 of 466
#
# ---------------------
# user 378 of 466
#
# ---------------------
# user 379 of 466
#
# ---------------------
# user 380 of 466
#
# ---------------------
# user 381 of 466
#
# ---------------------
# user 382 of 466
#
# ---------------------
# user 383 of 466
#
# ---------------------
# user 384 of 466
#
# ---------------------
# user 385 of 466
#
# ---------------------
# user 386 of 466
#
# ---------------------
# user 387 of 466
#
# ---------------------
# user 388 of 466
#
# ---------------------
# user 389 of 466
#
# ---------------------
# user 390 of 466
#
# ---------------------
# user 391 of 466
#
# ---------------------
# user 392 of 466
#
# ---------------------
# user 393 of 466
#
# ---------------------
# user 394 of 466
#
# ---------------------
# user 395 of 466
#
# ---------------------
# user 396 of 466
#
# ---------------------
# user 397 of 466
#
# ---------------------
# user 398 of 466
#
# ---------------------
# user 399 of 466
#
# ---------------------
# user 400 of 466
#
# ---------------------
# user 401 of 466
#
# ---------------------
# user 402 of 466
#
# ---------------------
# user 403 of 466
#
# ---------------------
# user 404 of 466
#
# ---------------------
# user 405 of 466
#
# ---------------------
# user 406 of 466
#
# ---------------------
# user 407 of 466
#
# ---------------------
# user 408 of 466
#
# ---------------------
# user 409 of 466
#
# ---------------------
# user 410 of 466
#
# ---------------------
# user 411 of 466
#
# ---------------------
# user 412 of 466
#
# ---------------------
# user 413 of 466
#
# ---------------------
# user 414 of 466
#
# ---------------------
# user 415 of 466
#
# ---------------------
# user 416 of 466
#
# ---------------------
# user 417 of 466
#
# ---------------------
# user 418 of 466
#
# ---------------------
# user 419 of 466
#
# ---------------------
# user 420 of 466
#
# ---------------------
# user 421 of 466
#
# ---------------------
# user 422 of 466
#
# ---------------------
# user 423 of 466
#
# ---------------------
# user 424 of 466
# ---------------------
# user 425 of 466
#
# ---------------------
# user 426 of 466
#
# ---------------------
# user 427 of 466
#
# ---------------------
# user 428 of 466
#
# ---------------------
# user 429 of 466
#
# ---------------------
# user 430 of 466
#
# ---------------------
# user 431 of 466
#
# ---------------------
# user 432 of 466
#
# ---------------------
# user 433 of 466
#
# ---------------------
# user 434 of 466
#
# ---------------------
# user 435 of 466
#
# ---------------------
# user 436 of 466
#
# ---------------------
# user 437 of 466
#
# ---------------------
# user 438 of 466
#
# ---------------------
# user 439 of 466
#
# ---------------------
# user 440 of 466
#
# ---------------------
# user 441 of 466
#
# ---------------------
# user 442 of 466
#
# ---------------------
# user 443 of 466
#
# ---------------------
# user 444 of 466
#
# ---------------------
# user 445 of 466
#
# ---------------------
# user 446 of 466
#
# ---------------------
# user 447 of 466
#
# ---------------------
# user 448 of 466
#
# ---------------------
# user 449 of 466
#
# ---------------------
# user 450 of 466
#
# ---------------------
# user 451 of 466
#
# ---------------------
# user 452 of 466
#
# ---------------------
# user 453 of 466
#
# ---------------------
# user 454 of 466
#
# ---------------------
# user 455 of 466
#
# ---------------------
# user 456 of 466
#
# ---------------------
# user 457 of 466
#
# ---------------------
# user 458 of 466
#
# ---------------------
# user 459 of 466
#
# ---------------------
# user 460 of 466
#
# ---------------------
# user 461 of 466
#
# ---------------------
# user 462 of 466
#
# ---------------------
# user 463 of 466
#
# ---------------------
# user 464 of 466
#
# ---------------------
# user 465 of 466
#           user                                              tweet  \
# 0  LeoAlvvesdf  O @ jornalnacional tá fazendo campanha para o ...
# 1  LeoAlvvesdf  Gostei de um vídeo @ YouTube http://youtu.be/-...
# 2  LeoAlvvesdf  Gostei de um vídeo @ YouTube http://youtu.be/X...
# 3  LeoAlvvesdf  Para que tá feio @ Haddad_Fernando! # MudaBras...
# 4  LeoAlvvesdf  Gostei de um vídeo @ YouTube http://youtu.be/L...
#
#                  date favorites retweets
# 0 2018-10-27 20:59:59         1        0
# 1 2018-10-27 12:23:51         0        0
# 2 2018-10-26 12:32:29         0        0
# 3 2018-10-26 08:18:59         1        0
# 4 2018-10-25 09:30:21         0        0

# %%
# BOZO
print('\n-----------------------\nBOZO TWEETS\n')
bozoTweets = makeQuery('bolsonaro',maxTweets=400)
users = map(lambda x: x.username, bozoTweets)
bozoHistoryTweets = pd.DataFrame(columns=['user','tweet','date','favorites','retweets'])
c = 0
for user in users:
    print('\n---------------------\nuser %i of %i' % (c,len(users)))
    c+=1
    tmp = makeQuery('bolsonaro',maxTweets=200,user=user)
    for i in tmp:
        bozoHistoryTweets = bozoHistoryTweets.append({
            'user': i.username,
            'tweet': i.text,
            'date': i.date,
            'favorites': i.favorites,
            'retweets': i.retweets
        }, ignore_index=True)

display(bozoHistoryTweets.head())
# Out:
# -----------------------
# BOZO TWEETS
#
#
# ---------------------
# user 0 of 351
#
# ---------------------
# user 1 of 351
#
# ---------------------
# user 2 of 351
#
# ---------------------
# user 3 of 351
#
# ---------------------
# user 4 of 351
#
# ---------------------
# user 5 of 351
#
# ---------------------
# user 6 of 351
#
# ---------------------
# user 7 of 351
#
# ---------------------
# user 8 of 351
#
# ---------------------
# user 9 of 351
#
# ---------------------
# user 10 of 351
#
# ---------------------
# user 11 of 351
#
# ---------------------
# user 12 of 351
#
# ---------------------
# user 13 of 351
#
# ---------------------
# user 14 of 351
#
# ---------------------
# user 15 of 351
#
# ---------------------
# user 16 of 351
#
# ---------------------
# user 17 of 351
#
# ---------------------
# user 18 of 351
#
# ---------------------
# user 19 of 351
#
# ---------------------
# user 20 of 351
#
# ---------------------
# user 21 of 351
#
# ---------------------
# user 22 of 351
#
# ---------------------
# user 23 of 351
#
# ---------------------
# user 24 of 351
#
# ---------------------
# user 25 of 351
#
# ---------------------
# user 26 of 351
#
# ---------------------
# user 27 of 351
#
# ---------------------
# user 28 of 351
#
# ---------------------
# user 29 of 351
#
# ---------------------
# user 30 of 351
#
# ---------------------
# user 31 of 351
#
# ---------------------
# user 32 of 351
#
# ---------------------
# user 33 of 351
#
# ---------------------
# user 34 of 351
#
# ---------------------
# user 35 of 351
#
# ---------------------
# user 36 of 351
#
# ---------------------
# user 37 of 351
#
# ---------------------
# user 38 of 351
#
# ---------------------
# user 39 of 351
#
# ---------------------
# user 40 of 351
#
# ---------------------
# user 41 of 351
#
# ---------------------
# user 42 of 351
#
# ---------------------
# user 43 of 351
#
# ---------------------
# user 44 of 351
#
# ---------------------
# user 45 of 351
#
# ---------------------
# user 46 of 351
#
# ---------------------
# user 47 of 351
#
# ---------------------
# user 48 of 351
#
# ---------------------
# user 49 of 351
#
# ---------------------
# user 50 of 351
#
# ---------------------
# user 51 of 351
#
# ---------------------
# user 52 of 351
#
# ---------------------
# user 53 of 351
#
# ---------------------
# user 54 of 351
#
# ---------------------
# user 55 of 351
#
# ---------------------
# user 56 of 351
#
# ---------------------
# user 57 of 351
#
# ---------------------
# user 58 of 351
#
# ---------------------
# user 59 of 351
#
# ---------------------
# user 60 of 351
#
# ---------------------
# user 61 of 351
#
# ---------------------
# user 62 of 351
#
# ---------------------
# user 63 of 351
#
# ---------------------
# user 64 of 351
#
# ---------------------
# user 65 of 351
#
# ---------------------
# user 66 of 351
#
# ---------------------
# user 67 of 351
#
# ---------------------
# user 68 of 351
#
# ---------------------
# user 69 of 351
#
# ---------------------
# user 70 of 351
#
# ---------------------
# user 71 of 351
#
# ---------------------
# user 72 of 351
#
# ---------------------
# user 73 of 351
#
# ---------------------
# user 74 of 351
#
# ---------------------
# user 75 of 351
#
# ---------------------
# user 76 of 351
#
# ---------------------
# user 77 of 351
#
# ---------------------
# user 78 of 351
#
# ---------------------
# user 79 of 351
#
# ---------------------
# user 80 of 351
#
# ---------------------
# user 81 of 351
#
# ---------------------
# user 82 of 351
#
# ---------------------
# user 83 of 351
#
# ---------------------
# user 84 of 351
#
# ---------------------
# user 85 of 351
#
# ---------------------
# user 86 of 351
#
# ---------------------
# user 87 of 351
#
# ---------------------
# user 88 of 351
#
# ---------------------
# user 89 of 351
#
# ---------------------
# user 90 of 351
#
# ---------------------
# user 91 of 351
#
# ---------------------
# user 92 of 351
#
# ---------------------
# user 93 of 351
#
# ---------------------
# user 94 of 351
#
# ---------------------
# user 95 of 351
#
# ---------------------
# user 96 of 351
#
# ---------------------
# user 97 of 351
#
# ---------------------
# user 98 of 351
#
# ---------------------
# user 99 of 351
#
# ---------------------
# user 100 of 351
#
# ---------------------
# user 101 of 351
#
# ---------------------
# user 102 of 351
#
# ---------------------
# user 103 of 351
#
# ---------------------
# user 104 of 351
#
# ---------------------
# user 105 of 351
#
# ---------------------
# user 106 of 351
#
# ---------------------
# user 107 of 351
#
# ---------------------
# user 108 of 351
#
# ---------------------
# user 109 of 351
#
# ---------------------
# user 110 of 351
#
# ---------------------
# user 111 of 351
#
# ---------------------
# user 112 of 351
#
# ---------------------
# user 113 of 351
#
# ---------------------
# user 114 of 351
#
# ---------------------
# user 115 of 351
#
# ---------------------
# user 116 of 351
#
# ---------------------
# user 117 of 351
#
# ---------------------
# user 118 of 351
#
# ---------------------
# user 119 of 351
#
# ---------------------
# user 120 of 351
#
# ---------------------
# user 121 of 351
#
# ---------------------
# user 122 of 351
#
# ---------------------
# user 123 of 351
#
# ---------------------
# user 124 of 351
#
# ---------------------
# user 125 of 351
#
# ---------------------
# user 126 of 351
#
# ---------------------
# user 127 of 351
#
# ---------------------
# user 128 of 351
#
# ---------------------
# user 129 of 351
#
# ---------------------
# user 130 of 351
#
# ---------------------
# user 131 of 351
#
# ---------------------
# user 132 of 351
#
# ---------------------
# user 133 of 351
#
# ---------------------
# user 134 of 351
#
# ---------------------
# user 135 of 351
#
# ---------------------
# user 136 of 351
#
# ---------------------
# user 137 of 351
#
# ---------------------
# user 138 of 351
#
# ---------------------
# user 139 of 351
#
# ---------------------
# user 140 of 351
#
# ---------------------
# user 141 of 351
#
# ---------------------
# user 142 of 351
#
# ---------------------
# user 143 of 351
#
# ---------------------
# user 144 of 351
#
# ---------------------
# user 145 of 351
#
# ---------------------
# user 146 of 351
#
# ---------------------
# user 147 of 351
#
# ---------------------
# user 148 of 351
#
# ---------------------
# user 149 of 351
#
# ---------------------
# user 150 of 351
#
# ---------------------
# user 151 of 351
#
# ---------------------
# user 152 of 351
#
# ---------------------
# user 153 of 351
#
# ---------------------
# user 154 of 351
#
# ---------------------
# user 155 of 351
#
# ---------------------
# user 156 of 351
#
# ---------------------
# user 157 of 351
#
# ---------------------
# user 158 of 351
#
# ---------------------
# user 159 of 351
#
# ---------------------
# user 160 of 351
#
# ---------------------
# user 161 of 351
#
# ---------------------
# user 162 of 351
#
# ---------------------
# user 163 of 351
#
# ---------------------
# user 164 of 351
#
# ---------------------
# user 165 of 351
#
# ---------------------
# user 166 of 351
#
# ---------------------
# user 167 of 351
#
# ---------------------
# user 168 of 351
#
# ---------------------
# user 169 of 351
#
# ---------------------
# user 170 of 351
#
# ---------------------
# user 171 of 351
#
# ---------------------
# user 172 of 351
#
# ---------------------
# user 173 of 351
#
# ---------------------
# user 174 of 351
#
# ---------------------
# user 175 of 351
#
# ---------------------
# user 176 of 351
#
# ---------------------
# user 177 of 351
#
# ---------------------
# user 178 of 351
#
# ---------------------
# user 179 of 351
#
# ---------------------
# user 180 of 351
#
# ---------------------
# user 181 of 351
#
# ---------------------
# user 182 of 351
#
# ---------------------
# user 183 of 351
#
# ---------------------
# user 184 of 351
#
# ---------------------
# user 185 of 351
#
# ---------------------
# user 186 of 351
#
# ---------------------
# user 187 of 351
#
# ---------------------
# user 188 of 351
#
# ---------------------
# user 189 of 351
#
# ---------------------
# user 190 of 351
#
# ---------------------
# user 191 of 351
#
# ---------------------
# user 192 of 351
#
# ---------------------
# user 193 of 351
#
# ---------------------
# user 194 of 351
#
# ---------------------
# user 195 of 351
#
# ---------------------
# user 196 of 351
#
# ---------------------
# user 197 of 351
#
# ---------------------
# user 198 of 351
#
# ---------------------
# user 199 of 351
#
# ---------------------
# user 200 of 351
#
# ---------------------
# user 201 of 351
#
# ---------------------
# user 202 of 351
#
# ---------------------
# user 203 of 351
#
# ---------------------
# user 204 of 351
#
# ---------------------
# user 205 of 351
#
# ---------------------
# user 206 of 351
#
# ---------------------
# user 207 of 351
#
# ---------------------
# user 208 of 351
#
# ---------------------
# user 209 of 351
#
# ---------------------
# user 210 of 351
#
# ---------------------
# user 211 of 351
# ---------------------
# user 212 of 351
#
# ---------------------
# user 213 of 351
#
# ---------------------
# user 214 of 351
#
# ---------------------
# user 215 of 351
#
# ---------------------
# user 216 of 351
#
# ---------------------
# user 217 of 351
#
# ---------------------
# user 218 of 351
#
# ---------------------
# user 219 of 351
#
# ---------------------
# user 220 of 351
#
# ---------------------
# user 221 of 351
#
# ---------------------
# user 222 of 351
#
# ---------------------
# user 223 of 351
#
# ---------------------
# user 224 of 351
#
# ---------------------
# user 225 of 351
#
# ---------------------
# user 226 of 351
#
# ---------------------
# user 227 of 351
#
# ---------------------
# user 228 of 351
#
# ---------------------
# user 229 of 351
#
# ---------------------
# user 230 of 351
#
# ---------------------
# user 231 of 351
#
# ---------------------
# user 232 of 351
#
# ---------------------
# user 233 of 351
#
# ---------------------
# user 234 of 351
#
# ---------------------
# user 235 of 351
#
# ---------------------
# user 236 of 351
#
# ---------------------
# user 237 of 351
#
# ---------------------
# user 238 of 351
#
# ---------------------
# user 239 of 351
#
# ---------------------
# user 240 of 351
#
# ---------------------
# user 241 of 351
#
# ---------------------
# user 242 of 351
#
# ---------------------
# user 243 of 351
#
# ---------------------
# user 244 of 351
#
# ---------------------
# user 245 of 351
#
# ---------------------
# user 246 of 351
#
# ---------------------
# user 247 of 351
#
# ---------------------
# user 248 of 351
#
# ---------------------
# user 249 of 351
#
# ---------------------
# user 250 of 351
#
# ---------------------
# user 251 of 351
#
# ---------------------
# user 252 of 351
#
# ---------------------
# user 253 of 351
#
# ---------------------
# user 254 of 351
#
# ---------------------
# user 255 of 351
#
# ---------------------
# user 256 of 351
#
# ---------------------
# user 257 of 351
#
# ---------------------
# user 258 of 351
#
# ---------------------
# user 259 of 351
#
# ---------------------
# user 260 of 351
#
# ---------------------
# user 261 of 351
#
# ---------------------
# user 262 of 351
#
# ---------------------
# user 263 of 351
#
# ---------------------
# user 264 of 351
#
# ---------------------
# user 265 of 351
#
# ---------------------
# user 266 of 351
#
# ---------------------
# user 267 of 351
#
# ---------------------
# user 268 of 351
#
# ---------------------
# user 269 of 351
#
# ---------------------
# user 270 of 351
#
# ---------------------
# user 271 of 351
#
# ---------------------
# user 272 of 351
#
# ---------------------
# user 273 of 351
#
# ---------------------
# user 274 of 351
#
# ---------------------
# user 275 of 351
#
# ---------------------
# user 276 of 351
#
# ---------------------
# user 277 of 351
#
# ---------------------
# user 278 of 351
#
# ---------------------
# user 279 of 351
#
# ---------------------
# user 280 of 351
#
# ---------------------
# user 281 of 351
#
# ---------------------
# user 282 of 351
#
# ---------------------
# user 283 of 351
#
# ---------------------
# user 284 of 351
#
# ---------------------
# user 285 of 351
#
# ---------------------
# user 286 of 351
#
# ---------------------
# user 287 of 351
#
# ---------------------
# user 288 of 351
#
# ---------------------
# user 289 of 351
#
# ---------------------
# user 290 of 351
#
# ---------------------
# user 291 of 351
#
# ---------------------
# user 292 of 351
#
# ---------------------
# user 293 of 351
#
# ---------------------
# user 294 of 351
#
# ---------------------
# user 295 of 351
#
# ---------------------
# user 296 of 351
#
# ---------------------
# user 297 of 351
#
# ---------------------
# user 298 of 351
#
# ---------------------
# user 299 of 351
#
# ---------------------
# user 300 of 351
#
# ---------------------
# user 301 of 351
#
# ---------------------
# user 302 of 351
#
# ---------------------
# user 303 of 351
#
# ---------------------
# user 304 of 351
#
# ---------------------
# user 305 of 351
#
# ---------------------
# user 306 of 351
#
# ---------------------
# user 307 of 351
#
# ---------------------
# user 308 of 351
#
# ---------------------
# user 309 of 351
#
# ---------------------
# user 310 of 351
#
# ---------------------
# user 311 of 351
#
# ---------------------
# user 312 of 351
#
# ---------------------
# user 313 of 351
#
# ---------------------
# user 314 of 351
#
# ---------------------
# user 315 of 351
#
# ---------------------
# user 316 of 351
#
# ---------------------
# user 317 of 351
#
# ---------------------
# user 318 of 351
#
# ---------------------
# user 319 of 351
#
# ---------------------
# user 320 of 351
#
# ---------------------
# user 321 of 351
#
# ---------------------
# user 322 of 351
#
# ---------------------
# user 323 of 351
#
# ---------------------
# user 324 of 351
#
# ---------------------
# user 325 of 351
#
# ---------------------
# user 326 of 351
#
# ---------------------
# user 327 of 351
#
# ---------------------
# user 328 of 351
#
# ---------------------
# user 329 of 351
#
# ---------------------
# user 330 of 351
#
# ---------------------
# user 331 of 351
#
# ---------------------
# user 332 of 351
#
# ---------------------
# user 333 of 351
#
# ---------------------
# user 334 of 351
#
# ---------------------
# user 335 of 351
#
# ---------------------
# user 336 of 351
#
# ---------------------
# user 337 of 351
#
# ---------------------
# user 338 of 351
#
# ---------------------
# user 339 of 351
#
# ---------------------
# user 340 of 351
#
# ---------------------
# user 341 of 351
#
# ---------------------
# user 342 of 351
#
# ---------------------
# user 343 of 351
#
# ---------------------
# user 344 of 351
#
# ---------------------
# user 345 of 351
#
# ---------------------
# user 346 of 351
#
# ---------------------
# user 347 of 351
#
# ---------------------
# user 348 of 351
#
# ---------------------
# user 349 of 351
#
# ---------------------
# user 350 of 351
#           user                                              tweet  \
# 0  taissarubim  pessoas públicas não devem ter medo de expor s...
# 1  taissarubim  A projeção feita pro ano que vêm com as reform...
# 2  taissarubim  BOLSONARO PRESIDENTE - Como será? https://yout...
# 3  taissarubim  A parada é a seguinte: SE BOLSONARO FOR PRESID...
# 4  taissarubim  As FAKENEWS de Bolsonaro e Haddad / Canal Nost...
#
#                  date favorites retweets
# 0 2018-10-27 20:59:59         1        0
# 1 2018-10-27 20:48:39         0        0
# 2 2018-10-27 20:35:47         0        0
# 3 2018-10-26 17:35:28         6        0
# 4 2018-10-26 17:02:12         1        0

# %%
def altNameQuery(altName):
    print('\n-----------------------\n%s TWEETS\n'%altName)
    bozoAltTweets = makeQuery(altName,maxTweets=34)
    users = map(lambda x: x.username, bozoAltTweets)
    bozoAltHistoryTweets = pd.DataFrame(columns=['user','tweet','date','favorites','retweets'])
    c = 0
    for user in users:
        print('\n---------------------\nuser %i of %i' % (c,len(users)))
        c+=1
        tmp = makeQuery(altName,maxTweets=200,user=user)
        for i in tmp:
            bozoAltHistoryTweets = bozoAltHistoryTweets.append({
                'user': i.username,
                'tweet': i.text,
                'date': i.date,
                'favorites': i.favorites,
                'retweets': i.retweets
            }, ignore_index=True)

    return bozoAltHistoryTweets

# %%
# BOZO ALT NAMES
print('\n-----------------------\nBOZO ALT TWEETS\n')
altNames = ['bozonaro','salnorabo','bonoro']
bozoAltHistoryTweets = pd.DataFrame(columns=['user','tweet','date','favorites','retweets'])
for name in altNames:
    bozoAltHistoryTweets = bozoAltHistoryTweets.append(altNameQuery(name))
    
display(bozoAltHistoryTweets.head())
# Out:
# -----------------------
# BOZO ALT TWEETS
#
#
# -----------------------
# bozonaro TWEETS
#
#
# ---------------------
# user 0 of 32
#
# ---------------------
# user 1 of 32
#
# ---------------------
# user 2 of 32
#
# ---------------------
# user 3 of 32
#
# ---------------------
# user 4 of 32
#
# ---------------------
# user 5 of 32
#
# ---------------------
# user 6 of 32
#
# ---------------------
# user 7 of 32
#
# ---------------------
# user 8 of 32
#
# ---------------------
# user 9 of 32
#
# ---------------------
# user 10 of 32
#
# ---------------------
# user 11 of 32
#
# ---------------------
# user 12 of 32
#
# ---------------------
# user 13 of 32
#
# ---------------------
# user 14 of 32
#
# ---------------------
# user 15 of 32
#
# ---------------------
# user 16 of 32
#
# ---------------------
# user 17 of 32
#
# ---------------------
# user 18 of 32
#
# ---------------------
# user 19 of 32
#
# ---------------------
# user 20 of 32
#
# ---------------------
# user 21 of 32
#
# ---------------------
# user 22 of 32
#
# ---------------------
# user 23 of 32
#
# ---------------------
# user 24 of 32
#
# ---------------------
# user 25 of 32
#
# ---------------------
# user 26 of 32
#
# ---------------------
# user 27 of 32
#
# ---------------------
# user 28 of 32
#
# ---------------------
# user 29 of 32
#
# ---------------------
# user 30 of 32
#
# ---------------------
# user 31 of 32
#
# -----------------------
# salnorabo TWEETS
#
#
# ---------------------
# user 0 of 33
#
# ---------------------
# user 1 of 33
#
# ---------------------
# user 2 of 33
#
# ---------------------
# user 3 of 33
#
# ---------------------
# user 4 of 33
#
# ---------------------
# user 5 of 33
#
# ---------------------
# user 6 of 33
#
# ---------------------
# user 7 of 33
#
# ---------------------
# user 8 of 33
#
# ---------------------
# user 9 of 33
#
# ---------------------
# user 10 of 33
#
# ---------------------
# user 11 of 33
#
# ---------------------
# user 12 of 33
#
# ---------------------
# user 13 of 33
#
# ---------------------
# user 14 of 33
#
# ---------------------
# user 15 of 33
#
# ---------------------
# user 16 of 33
#
# ---------------------
# user 17 of 33
#
# ---------------------
# user 18 of 33
#
# ---------------------
# user 19 of 33
#
# ---------------------
# user 20 of 33
#
# ---------------------
# user 21 of 33
#
# ---------------------
# user 22 of 33
#
# ---------------------
# user 23 of 33
#
# ---------------------
# user 24 of 33
#
# ---------------------
# user 25 of 33
#
# ---------------------
# user 26 of 33
#
# ---------------------
# user 27 of 33
#
# ---------------------
# user 28 of 33
#
# ---------------------
# user 29 of 33
#
# ---------------------
# user 30 of 33
#
# ---------------------
# user 31 of 33
#
# ---------------------
# user 32 of 33
#
# -----------------------
# bonoro TWEETS
#
#
# ---------------------
# user 0 of 34
#
# ---------------------
# user 1 of 34
#
# ---------------------
# user 2 of 34
#
# ---------------------
# user 3 of 34
#
# ---------------------
# user 4 of 34
#
# ---------------------
# user 5 of 34
#
# ---------------------
# user 6 of 34
#
# ---------------------
# user 7 of 34
#
# ---------------------
# user 8 of 34
#
# ---------------------
# user 9 of 34
#
# ---------------------
# user 10 of 34
#
# ---------------------
# user 11 of 34
#
# ---------------------
# user 12 of 34
#
# ---------------------
# user 13 of 34
#
# ---------------------
# user 14 of 34
#
# ---------------------
# user 15 of 34
#
# ---------------------
# user 16 of 34
#
# ---------------------
# user 17 of 34
#
# ---------------------
# user 18 of 34
#
# ---------------------
# user 19 of 34
#
# ---------------------
# user 20 of 34
#
# ---------------------
# user 21 of 34
#
# ---------------------
# user 22 of 34
#
# ---------------------
# user 23 of 34
#
# ---------------------
# user 24 of 34
#
# ---------------------
# user 25 of 34
#
# ---------------------
# user 26 of 34
#
# ---------------------
# user 27 of 34
#
# ---------------------
# user 28 of 34
#
# ---------------------
# user 29 of 34
#
# ---------------------
# user 30 of 34
#
# ---------------------
# user 31 of 34
#
# ---------------------
# user 32 of 34
#
# ---------------------
# user 33 of 34
#            user                                              tweet  \
# 0  ambitchiious  você usa droga, ama um baile de favela, aborto...
# 1  ambitchiious  o bozonaro foi ferido com uma arma branca, ima...
# 2       kevysu1                  fala cotista que apoia o bozonaro
# 3       kevysu1                          Aqui é bozonaro 2018 Flws
# 4       kevysu1  se algum eleitor do bozonaro me segue pfvr faç...
#
#                  date favorites retweets
# 0 2018-10-27 20:59:33         1        0
# 1 2018-09-06 16:37:13         0        0
# 2 2018-10-27 20:59:16         0        0
# 3 2018-08-20 19:25:23         0        0
# 4 2018-07-20 10:09:29         4        1

# %%
#remove tweets that contains bolsonaro and haddad comments together
cleanBozoTweets = bozoHistoryTweets[bozoHistoryTweets.tweet.str.contains('lula|haddad|pt')]
cleanHaddadTweets = haddadHistoryTweets[haddadHistoryTweets.tweet.str.contains('bolsonaro')]

def removeLink(string):
    return re.sub(r'http\S+', '', string)

linkRemover = lambda x: removeLink(x)

#removendo links
cleanBozoTweets = cleanBozoTweets['tweet'].apply(linkRemover)
cleanHaddadTweets = cleanHaddadTweets['tweet'].apply(linkRemover)
print(bozoHistoryTweets)

cleanHaddadTweets.to_csv('haddad.csv',sep=',',encoding='utf-8')
cleanBozoTweets.to_csv('bozo.csv',sep=',',encoding='utf-8')
bozoAltHistoryTweets.to_csv('bozoAlt.csv',sep=',',encoding='utf-8')
# Out:
#                 user                                              tweet  \
# 0        taissarubim  pessoas públicas não devem ter medo de expor s...
# 1        taissarubim  A projeção feita pro ano que vêm com as reform...
# 2        taissarubim  BOLSONARO PRESIDENTE - Como será? https://yout...
# 3        taissarubim  A parada é a seguinte: SE BOLSONARO FOR PRESID...
# 4        taissarubim  As FAKENEWS de Bolsonaro e Haddad / Canal Nost...
# 5        taissarubim  O Brasil que eu quero é um Brasil onde a violê...
# 6        taissarubim  Jair Bolsonaro foi esfaqueado em Juíz de fora ...
# 7        taissarubim  AH NÃO, gente! aí já é demais! Uma coisa é voc...
# 8      ruby_pedagoga  Os valores da família empurram a candidatura d...
# 9      ruby_pedagoga  Plano educacional de Bolsonaro une criação de ...
# 10     ruby_pedagoga  Janaína afirma “Votar em Bolsonaro virou ato d...
# 11     ruby_pedagoga  Pesquisa Ibope para presidente: Bolsonaro, 31%...
# 12           celo106  Tenhamos um domingo abençoado, a mudança começ...
# 13           celo106  Os petralhas podem chamar o Jair messias Bolso...
# 14           celo106  Estou vendo várias pessoas dizerem se o messia...
# 15           celo106  Galera apoiadores do messias Jair Bolsonaro, e...
# 16           celo106  Jair messias Bolsonaro, melhor caminho, melhor...
# 17           celo106  As eleições estão chegando e o messias Jair Bo...
# 18           celo106  Galera apoiadores do messias Jair Bolsonaro, o...
# 19           celo106  Povo do nordeste ou amado povo nordestino, se ...
# 20           celo106  O que é nível de confiança de uma pesquisa ele...
# 21           celo106  Galera que apoia Jair messias Bolsonaro faltam...
# 22           celo106  A certeza da derrota é tão grande que o candid...
# 23           celo106  Terminado este dia de eleições o messias Jair ...
# 24           celo106  A mudança é Jair Messias Bolsonaro presidente ...
# 25             LM8W7  Esperando a matéria no JN tbm sobre Bolsonaro,...
# 26             LM8W7  @ jairbolsonaro Estou aqui com minha Prole, as...
# 27             LM8W7  @ jairbolsonaro Fala Capitão, 01 fale um pouco...
# 28             LM8W7  E essa editora falida ainda tem algum crédito?...
# 29             LM8W7  @ RedeGlobo Falando o Nome de @ jairbolsonaro ...
# ...              ...                                                ...
# 20988      lia_losan  Essa Miriam Leitão levou umas na “Ditadura”, e...
# 20989      lia_losan  Esses peritos de rede social... Já leu o que o...
# 20990      lia_losan  Gente, o advogado do maluco que atacou @ jairb...
# 20991      lia_losan  Todos podem falar sobre matar, mas @ jairbolso...
# 20992      lia_losan  Hoje eu vi o comercial ainda difamando @ jairb...
# 20993      lia_losan  Vão continuar espalhando o ódio contra @ jairb...
# 20994      lia_losan  "Acirrar os ânimos", pra não falar, aumentar o...
# 20995      lia_losan  Ahaaaaaaaam lamenta sim. A gente percebe que v...
# 20996      lia_losan  Filiados do # PSOL se "solidarizando" com o at...
# 20997      lia_losan  Falas de comedores de capim: -Bolsonaro incita...
# 20998      lia_losan  Parabéns # Alckmin e candidatos à presidência....
# 20999      lia_losan  # Bolsonaro está em ótimas mãos, sairá bem. De...
# 21000      lia_losan  Já estou vendo jumentos falando: “imagina se o...
# 21001      lia_losan  Será que tem rede de televisão envolvida no at...
# 21002      lia_losan  Depois a direita que é fascista? Isso tudo é a...
# 21003      lia_losan                  Em que ano ele falou isso? Ah tá.
# 21004      lia_losan  Realmente tem necessidade de fazer propaganda ...
# 21005      lia_losan  # BolsonaroaNoJornalNacional que hipocrisia de...
# 21006      lia_losan  Com hashtag do Bolsonaro já bloquearam minha c...
# 21007      lia_losan  # DebateRedeTV tem medo do Bolsonaro mostrar q...
# 21008      lia_losan  # Twitter tá com problema pra escrever # Bolso...
# 21009      lia_losan  # DebateRedeTV Boulos tem uma cara de sínico. ...
# 21010      lia_losan  # DebateRedeTV Boulos tá querendo sempre levar...
# 21011      lia_losan  # DebateRedeTV # Bolsonaro é gente como a gent...
# 21012      lia_losan  Tava errado? Não. Só vai contra quem não gosta...
# 21013      lia_losan  Sim, Boulos, muitos foram financiados por empr...
# 21014      lia_losan  # BolsonaroNaRedeTV # DebateRedeTV Impressão m...
# 21015      lia_losan  # DebateRedeTV Agora eu pergunto: # Bolsonaro ...
# 21016      lia_losan  # DebateRedeTV “não existe 35 ideologias”. Cla...
# 21017      lia_losan  # debatebandrio ñ assisti do início.Será q per...
#
#                      date favorites retweets
# 0     2018-10-27 20:59:59         1        0
# 1     2018-10-27 20:48:39         0        0
# 2     2018-10-27 20:35:47         0        0
# 3     2018-10-26 17:35:28         6        0
# 4     2018-10-26 17:02:12         1        0
# 5     2018-09-06 18:04:17         1        0
# 6     2018-09-06 17:56:45         1        0
# 7     2018-09-06 17:17:16         4        2
# 8     2018-10-27 20:59:59         0        0
# 9     2018-10-22 12:50:00         0        0
# 10    2018-10-21 19:53:49         0        0
# 11    2018-10-01 22:32:21         0        1
# 12    2018-10-27 20:59:59         0        0
# 13    2018-10-25 22:42:40         0        0
# 14    2018-10-25 00:18:24         0        0
# 15    2018-10-24 14:58:19         0        0
# 16    2018-10-23 00:05:31         0        0
# 17    2018-10-21 18:35:41         0        0
# 18    2018-10-16 23:53:33         0        0
# 19    2018-10-15 21:44:00         0        0
# 20    2018-10-15 21:13:48         0        0
# 21    2018-10-14 22:46:14         0        0
# 22    2018-10-13 00:06:34         0        0
# 23    2018-10-07 23:31:32         0        0
# 24    2018-08-04 00:12:34         0        0
# 25    2018-10-27 20:59:58         2        0
# 26    2018-10-21 19:31:01         0        0
# 27    2018-10-10 01:16:42         0        0
# 28    2018-10-01 07:05:42         1        0
# 29    2018-07-22 21:52:58         0        0
# ...                   ...       ...      ...
# 20988 2018-09-09 01:06:06         0        0
# 20989 2018-09-09 00:52:21         0        0
# 20990 2018-09-07 22:10:44         0        0
# 20991 2018-09-07 21:09:28         0        0
# 20992 2018-09-07 20:53:59         0        1
# 20993 2018-09-07 12:39:03         0        0
# 20994 2018-09-06 19:50:54         0        0
# 20995 2018-09-06 19:48:35         0        0
# 20996 2018-09-06 19:32:10         0        0
# 20997 2018-09-06 18:42:50         0        0
# 20998 2018-09-06 17:49:18         0        0
# 20999 2018-09-06 17:26:28         0        0
# 21000 2018-09-06 17:19:41         0        0
# 21001 2018-09-06 16:58:09         0        0
# 21002 2018-09-06 16:54:43         0        0
# 21003 2018-09-04 17:37:45         0        0
# 21004 2018-09-04 17:33:03         0        1
# 21005 2018-08-29 00:20:04         0        0
# 21006 2018-08-27 20:22:13         0        0
# 21007 2018-08-18 00:09:29         0        0
# 21008 2018-08-18 00:07:01         0        0
# 21009 2018-08-18 00:02:04         0        0
# 21010 2018-08-17 23:56:22         1        0
# 21011 2018-08-17 23:52:46         2        0
# 21012 2018-08-17 22:57:37         0        0
# 21013 2018-08-17 22:54:57         0        0
# 21014 2018-08-17 22:53:11         0        0
# 21015 2018-08-17 22:24:48         1        0
# 21016 2018-08-17 22:20:23         0        0
# 21017 2018-08-17 01:07:07         0        0
#
# [21018 rows x 5 columns]

# %%
#analise de sentimentos
from textblob import TextBlob
def analyzeText(txt):
    frase = TextBlob(txt.decode('utf-8'))
    if frase.detect_language() != 'en':
        traducao = TextBlob(str(frase.translate(to='en')))
        return traducao.sentiment
    else:
        return frase.sentiment
print(analyzeText("eu nao estou muito feliz com bolsonaro"))
# Out:
# Sentiment(polarity=-0.3076923076923077, subjectivity=0.7692307692307692)

# %%
bozo = bozoHistoryTweets
print(bozo.head())
analyze = lambda x: analyzeText(x)
#capitalizer = lambda x: x.upper()
#a = bozo['tweet'].apply (analyze)
#print(a)
#print(bozo)

#df['name'].apply(capitalizer)
# Out:
#           user                                              tweet  \
# 0  taissarubim  pessoas públicas não devem ter medo de expor s...
# 1  taissarubim  A projeção feita pro ano que vêm com as reform...
# 2  taissarubim  BOLSONARO PRESIDENTE - Como será? https://yout...
# 3  taissarubim  A parada é a seguinte: SE BOLSONARO FOR PRESID...
# 4  taissarubim  As FAKENEWS de Bolsonaro e Haddad / Canal Nost...
#
#                  date favorites retweets
# 0 2018-10-27 20:59:59         1        0
# 1 2018-10-27 20:48:39         0        0
# 2 2018-10-27 20:35:47         0        0
# 3 2018-10-26 17:35:28         6        0
# 4 2018-10-26 17:02:12         1        0
# UnicodeEncodeErrorTraceback (most recent call last)
# <ipython-input-31-448d6abb58e4> in <module>()
#       3 analyze = lambda x: analyzeText(x)
#       4 capitalizer = lambda x: x.upper()
# ----> 5 a = bozo['tweet'].apply (analyze)
#       6 print(a)
#       7 #print(bozo)
#
# c:\python27\lib\site-packages\pandas\core\series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-31-448d6abb58e4> in <lambda>(x)
#       1 bozo = bozoHistoryTweets
#       2 print(bozo.head())
# ----> 3 analyze = lambda x: analyzeText(x)
#       4 capitalizer = lambda x: x.upper()
#       5 a = bozo['tweet'].apply (analyze)
#
# <ipython-input-30-9498c395806c> in analyzeText(txt)
#       2 from textblob import TextBlob
#       3 def analyzeText(txt):
# ----> 4     frase = TextBlob(txt.decode('latin'))
#       5     if frase.detect_language() != 'en':
#       6         traducao = TextBlob(str(frase.translate(to='en')))
#
# UnicodeEncodeError: 'ascii' codec can't encode character u'\xfa' in position 9: ordinal not in range(128)

# %%
data = {'name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'year': [2012, 2012, 2013, 2014, 2014], 
        'reports': [4, 24, 31, 2, 3],
        'coverage': [25, 94, 57, 62, 70]}
df = pd.DataFrame(data, index = ['Cochice', 'Pima', 'Santa Cruz', 'Maricopa', 'Yuma'])
df
capitalizer = lambda x: x.upper()
df['name'].apply(capitalizer)
# Out:
# Cochice       JASON
# Pima          MOLLY
# Santa Cruz     TINA
# Maricopa       JAKE
# Yuma            AMY
# Name: name, dtype: object
